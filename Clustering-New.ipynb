# %%
import pandas as pd
import numpy as np
import re
import nltk
from datetime import datetime
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.cluster import KMeansClusterer
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn import cluster
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import AgglomerativeClustering
from sentence_transformers import SentenceTransformer

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/matthewlucich/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#df_polusa_raw = pd.read_csv("2017_unbalanced.csv")
df_polusa_raw = pd.read_csv("2019_unbalanced.csv")

# %%
df_polusa_raw.shape
# Out:
# (110193, 10)

# %%
df_polusa = df_polusa_raw.dropna()

# %%
df_polusa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93610 entries, 0 to 110192
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 93610 non-null  int64
#  1   date_publish       93610 non-null  object
#  2   outlet             93610 non-null  object
#  3   headline           93610 non-null  object
#  4   lead               93610 non-null  object
#  5   body               93610 non-null  object
#  6   authors            93610 non-null  object
#  7   domain             93610 non-null  object
#  8   url                93610 non-null  object
#  9   political_leaning  93610 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 7.9+ MB

# %%
df_polusa['headline'] = df_polusa['headline'].astype(str)
df_polusa['head_lead'] = df_polusa['headline'] + "###" + df_polusa['lead']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# ## Filter out irrelevant articles

# %%
df_polusa.head(2)
# Out:
#          id         date_publish              outlet  \
# 0  52876988  2019-07-01 00:00:00                 NPR
# 1   4011336  2019-07-01 00:00:00  The New York Times
#
#                                             headline  \
# 0  News Brief: Trump-Kim Weekend Meeting, Hong Ko...
# 1  Al Kelly of Visa on the Reagan White House and...
#
#                                                 lead  \
# 0  President Trump met North Korea's leader at th...
# 1  Everywhere and nowhere, he works to keep Visa ...
#
#                                                 body  \
# 0  News Brief: Trump-Kim Weekend Meeting, Hong Ko...
# 1  You’re very involved with the Catholic Church....
#
#                        authors           domain  \
# 0  Rachel Martin;Steve Inskeep      www.npr.org
# 1                 David Gelles  www.nytimes.com
#
#                                                  url political_leaning  \
# 0  https://www.npr.org/2019/07/01/737535379/morni...              LEFT
# 1  https://www.nytimes.com/2019/07/01/business/al...              LEFT
#
#                                            head_lead
# 0  News Brief: Trump-Kim Weekend Meeting, Hong Ko...
# 1  Al Kelly of Visa on the Reagan White House and...

# %%
df_polusa = df_polusa.loc[~df_polusa["url"].str.contains("opinion")] # Remove opinion
df_polusa = df_polusa.loc[~df_polusa["url"].str.contains("Your Monday Briefing")]
df_polusa = df_polusa.loc[~df_polusa["url"].str.contains("Shots - Health News")]
df_polusa = df_polusa.loc[~df_polusa["url"].str.contains("GLOBAL MARKETS-")]
df_polusa = df_polusa.loc[~df_polusa["url"].str.contains("CANADA STOCKS-")]
df_polusa = df_polusa.loc[~df_polusa["url"].str.contains("Reuters Select")]
df_polusa = df_polusa.loc[~df_polusa["url"].str.contains("From the archive")]
df_polusa = df_polusa.loc[~df_polusa["url"].str.contains("Happy Hour Roundup")]

# %%
location_stock = "US STOCKS|UK Stocks|German stocks|Korean stocks|HK stocks|European stocks" + \
                 "China stocks|Hong Kong stocks|Asia Stocks|Global stocks|CANADA STOCKS|MIDEAST STOCKS" + \
                 "Swiss stocks|Latam stocks|Japanese stocks|Benelux stocks|S&P 500"   
df_polusa = df_polusa.loc[~df_polusa["url"].str.contains(location_stock)]

# %%
subject_mkt = "stock|bond|futures"
verb_mkt = "yield|rally|gain|extend loss|drop|slip|slide|fall|rise|climb|lower|volatile|edge higer"
df_polusa = df_polusa.loc[(~df_polusa["url"].str.contains(subject_mkt)) & 
                          (~df_polusa["url"].str.contains(verb_mkt))]

# %%
#df_polusa.loc[df_polusa["headline"].str.contains("stock")]["headline"]

# %% [markdown]
# ## Subset data

# %%
df_polusa = df_polusa.iloc[-5000:, :]

# %% [markdown]
# ## Add date to corpus embeddings

# %%
temp_list = df_polusa["date_publish"].to_list()

# %%
max(df_polusa["date_publish"])
# Out:
# '2019-08-31 23:47:08'

# %%
min_date = datetime.strptime(min(df_polusa["date_publish"]), '%Y-%m-%d %H:%M:%S')

# %%
def convert_to_days(date_str):
    temp_date = datetime.strptime(date_str, '%Y-%m-%d %H:%M:%S')
    #days_since = (temp_date - datetime(1970,1,1)).total_seconds()
    days_since = (temp_date - min_date).total_seconds()
    return days_since

# %%
time_list = np.array([convert_to_days(art_date) for art_date in temp_list])

# %%
v = time_list
time_list_minmax = (v - v.min()) / (v.max() - v.min())

# %%
len(time_list)
# Out:
# 5000

# %%
date_shaped = time_list_minmax.reshape(len(time_list_minmax), 1)

# %% [markdown]
# ## Corpus Embeddings

# %%
embedder = SentenceTransformer('all-MiniLM-L6-v2') # 'distilbert-base-nli-mean-tokens'

#corpus = df_polusa.iloc[0:15000, :]["head_lead"].to_list()
corpus = df_polusa["head_lead"].to_list()

corpus_embeddings = embedder.encode(corpus, show_progress_bar=True)

# Normalize the embeddings to unit length
corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)
# Out:
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]

# %%
corpus_embeddings_date  = np.hstack((corpus_embeddings, date_shaped))

# %% [markdown]
# ## Clustering

# %% [markdown]
# #### HDBSCAN Clustering

# %%
# import hdbscan

# %%
# cluster_hdbscan = hdbscan.HDBSCAN(min_cluster_size=3,
#                           metric='manhattan',  min_samples=100,                    
#                           cluster_selection_method='eom').fit(corpus_embeddings_date)

# %%
# df_polusa["cluster_hdbs"] = cluster_hdbscan.labels_

# %%
# len(set(df_polusa["cluster_hdbs"]))
# Out:
# 4

# %%
# cluster_assignment = cluster_hdbscan.labels_

# %%
# clustered_sentences = {}
# for sentence_id, cluster_id in enumerate(cluster_assignment):
#     if cluster_id not in clustered_sentences:
#         clustered_sentences[cluster_id] = []

#     clustered_sentences[cluster_id].append(corpus[sentence_id])

# %%
# for i, cluster in clustered_sentences.items():
#     print("Cluster ", i)
#     for article in cluster:
#         print(article.split("###")[0])
#     print("")

# %% [markdown]
# #### Agglomerative Clustering

# %%
# Perform kmean clustering
clustering_model = AgglomerativeClustering(n_clusters=None, distance_threshold=1.25) # 1.5 #, affinity='cosine', linkage='average', distance_threshold=0.4)
clustering_model.fit(corpus_embeddings_date)
cluster_assignment = clustering_model.labels_

clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences:
        clustered_sentences[cluster_id] = []

    clustered_sentences[cluster_id].append(corpus[sentence_id])

# %%
for i, cluster in clustered_sentences.items():
    print("Cluster ", i)
    for article in cluster:
        print(article.split("###")[0])
    print("")
# Out:
# Cluster  185
# Russia's Polymetal may consider special dividend payout: CFO
# Finland's Solidium plans to cut number of holdings over time
#
# Cluster  1366
# CORRECTED-Chinese steel maker picks additional 24% stake in Global Switch
# Chinese steel maker picks additional 24% stake in Global Switch ahead of IPO
#
# Cluster  1336
# UPDATE 1-Erdogan says Turkey wants to continue defence cooperation with Russia
# Erdogan says Turkey wants to continue defense cooperation with Russia
# Russia, Turkey agree steps to tackle militants in Syria's Idlib: Putin
#
# Cluster  42
# UPDATE 1-Zambian court suspends KCM wind-up hearing pending appeal ruling
# U.S. appeals court revives aluminum antitrust cases vs Goldman, JPMorgan, Glencore
# Appeals court: New Orleans judges have conflict on fines
# CVS fights ex-exec's appellate bid to join Amazon's PillPack
# 11th Circuit revives would-be class action over credit union's overdraft fees
#
# Cluster  1128
# Argentina's Macri says inflation rising, central bank props up peso
# Argentina sells $302 million in reserves to support peso, breaking IMF guideline
#
# Cluster  125
# Water Scarcity Is A Growing Problem. We Can Use Satellites To Better Measure It.
# Are water shortages driving migration? Researchers dispel myths
# Water costs are rising across the U.S. - here's why
# More people, less water? Scientists see risks on upper Nile
# More people, less water? Scientists see risks on upper Nile
#
# Cluster  1198
# Brexit: Ireland says British proposals don't come close to replacing backstop
# Brexit: Ireland says UK proposals don't come close to replacing backstop
# Irish stance on backstop won't change due to UK parliament suspension - minister
# Brexit: Ireland will not support abolition of backstop, says Coveney
# Brexit: Ireland will not support removing backstop, says Coveney
#
# Cluster  1330
# Israel’s shadow war with Iran bursts into the open
# Israel's shadow war with Iran bursts into the open
# The Israel-Iran Shadow War Escalates and Breaks Into the Open
# Israel's shadow war with Iran risks triggering wider conflict, analysts say
# Israel Is Escalating Its Shadow War With Iran. Here's What to Know
#
# Cluster  1305
# Brexit: Backstop plan by Sir Jonathan Faull dismissed by EU
# EU ready to look at 'realistic' backstop plans from Johnson
# Juncker tells Johnson EU support for Ireland is steadfast
# UK's Johnson tells Juncker no Brexit deal if backstop remains
# Johnson tells Juncker no Brexit deal if backstop remains
#
# Cluster  1014
# US drug czar James Carroll calls out drug companies for role in opioid crisis
# Responding to Trump, UPS and FedEx say they already fight illegal drug shipments
# Trump’s Opioid Deal Has Been a Big Success
#
# Cluster  1211
# China Ordains First Bishop Since Inking Deal with Vatican
# First Chinese bishop consecrated with pope’s OK after deal
# First Chinese Catholic bishop ordained with blessing of Pope Francis and Beijing
#
# Cluster  506
# New teachers can't afford the rent in all but one major U.S. city
# Teaching jobs go unfilled at rural schools
# Back to school, without a teacher: Inside the struggle to keep teachers at rural schools
#
# Cluster  907
# President Trump & Eugene Scalia -- Trump Nominates for Labor Secretary
# Trump formally nominates Scalia for labor secretary amid opposition from Dems, unions
# Labor nominee Eugene Scalia touted for expertise and experience, but faces stiff Dem opposition
#
# Cluster  118
# Investigation prompts rapid upgrades to asylum seekers' homes
# Shelter’s registration forms give portrait of asylum seekers
# 'No real security': why don't houseboat residents get rights like other tenants?
#
# Cluster  315
# I worked for Tim Bell. He was not the monster of leftwing caricature
# Meet The Teen Who Registered People To Vote While They Waited In Line At Popeyes
#
# Cluster  423
# National Poll: Bernie Sanders Slowly Closing the Gap on Joe Biden
# 2020 Daily Trail Markers: Biden's team disputes poll showing him behind
# Polling Picture Comes Into Focus: Biden Leads a 3-Way Race at the Top
# Joe Biden Leads Democrats in USA Today/Suffolk Poll
# Monmouth University renounces its own poll showing Biden plunging, calls it an ‘outlier’
# Biden back on top, enjoying wide leads in two new polls
# Poll Shows Biden, Four Other Democrats Leading Donald Trump
#
# Cluster  1122
# Norway urges its companies in Brazil to be mindful of deforestation
# Norway urges its companies in Brazil to safeguard the Amazon
#
# Cluster  1386
# Palestinian Harvard student denied entry to US because 'friends posted anti-American statements'
# Incoming Harvard freshman denied entry by immigration officials
# Student Says U.S. Immigration Denied Him Entry After Seeing Friends' Social Media Posts
# Harvard freshman deported after officials ‘find posts from his friends that oppose the US'
# Palestinian Harvard student says he was barred from US over friends' social media posts
# Harvard freshman denied U.S. entry after arriving from Lebanon
# Palestinian Harvard freshman, 17, allegedly blocked from entering US over friends' social media posts
# Questions after US turns away Palestinian Harvard freshman
#
# Cluster  1133
# Archbishop of Canterbury says he may chair Brexit citizens’ forum
# Justin Welby: investors must pressure firms to act on climate crisis
#
# Cluster  837
# Deputy who said he was shot by sniper has been investigated before
# LA County sheriff deputy may face criminal charge after faking being shot by sniper.
# Los Angeles Deputy Who Faked Sniper Attack Is Terminated, Sheriff Says
# California deputy, who allegedly made up story of being shot by a sniper, is fired
# LA sheriff's deputy fired after allegedly making up story about being shot by sniper
# L.A. County deputy who allegedly faked being shot is ousted
# California sheriff's deputy who admitted sniper hoax is fired
#
# Cluster  1031
# Gay Republican group's executive director resigns after Trump endorsement
# Executive director of pro-LGBT rights GOP group is the latest to leave after its endorsement of Trump
# Log Cabin Republicans resignations pile up with director's departure
# Another resignation shakes LGBT Republican group after Trump endorsement
#
# Cluster  381
# Lawsuit challenges Illinois license rule on head coverings
# Muslim inmates sue L.A. Sheriff's Department, alleging religious discrimination
# Lawsuit: Illinois secretary of state required Muslim woman to certify when she wears headscarf to receive driver’s license
#
# Cluster  1043
# Trump complains of ‘yet another big storm’ as Puerto Rico comes under a hurricane watch
# As another storm approaches Puerto Rico, President Trump is still taking jabs at his opponents there
# What he said about Puerto Rico and Fox News
# Trump Trashed Puerto Rico On Twitter As Island Braced For Hurricane Dorian
# 'Start Here': Trump takes aim at Puerto Rico as 2020 Senate fight heats up
#
# Cluster  640
# Brazil's central bank offers to sell dollars as real hits 2019 low
# UPDATE 1-Brazilian central bank intervenes in FX market as real hits 2019 low
# Brazil inflation on a downward path: central bank president
# Brazil bank lending down, default ratio up in July - central bank
#
# Cluster  1320
# Bernie bashes billionaires in manifesto to rescue the media
# U.S. presidential candidate Bernie Sanders takes aim at corporate media, tech giants
# Sanders has plan to help journalism
# Bernie’s Daft Plan to Save Journalism
#
# Cluster  602
# Trump disputes media report of bedbugs at Doral Miami resort
# Trump said his Florida resort where he wants to host the next G7 has 'no bed bugs.' The resort settled a lawsuit over bed bugs there in 2017
# Trump Blames Democrats For 'Nasty' Bedbugs Report At Doral Resort
# 'Not nice!': Trump denies rumors of bedbugs at resort he's promoting for G7
# 'Not nice!': Trump denies rumors of bedbugs at resort he's promoting for G7
# Trump denies bedbugs at his Doral resort. But inspectors have found a host of other problems.
#
# Cluster  976
# Presidential Hopeful Cory Booker Trails in Home State of New Jersey
# Cory Booker Defends Donations From Controversial New Jersey Political Bosses
# 'Cory Booker Is Not for the People'
#
# Cluster  818
# Bernie Sanders's China Comments -- China Has Done a Lot of Things for Their People!
# Sanders: China Has Made ‘More Progress’ on Extreme Poverty than Any Country in History
# Sanders praises China's 'progress' against 'extreme poverty': 'Done a lot of things for their people'
# Laura Ingraham: Bernie Sanders has 'soft spot' for 'Chinese thugs'
#
# Cluster  1146
# Hezbollah plans 'calculated' response to Israel: sources
# Hezbollah to hit back at Israel but war unlikely: deputy chief
# Lebanon’s Hezbollah group rules out wider war with Israel
# Hezbollah says will hit back at Israel as Lebanon fires at Israeli drones
#
# Cluster  680
# 2 largest settlements yet add $9M over deaths tied to doctor
# Ohio hospital where doctor accused of opioid murders worked settles lawsuits
# Doctor in murder case gets 2 new lawyers, June trial date
#
# Cluster  1010
# Brazil official says EU-Mercosur trade pact still under review
# Brazil official says EU-Mercosur trade pact still under review
# EU-Mercosur trade deal could be ready by late 2020 in best case: EU official
#
# Cluster  580
# Don't be fooled, this is a false dawn for the property market
# Rate cuts not enough to re-fire damp India housing market: Reuters poll
#
# Cluster  578
# North Dakota pledges improvement to spill reporting site
# Corps official: Study needed of Missouri River flood options
#
# Cluster  1103
# Gambia's first post-independence president Jawara dies at 95
# Gambia’s 1st president, Dawda Jawara, dies at 95
# Dawda Jawara, Gambian founding father who led country for 24 years, dies at 95
# Sir Dawda Jawara obituary
#
# Cluster  1106
# Coalition talks resume in effort to avert snap elections in Italy
# Trump weighs in as Italians toil to form a new government
# Italy inches closer to new government as parties haggle
# New Italian coalition allies have mutual foe, but little else in common
# 5-Star online vote could yet scupper Italy's nascent government
#
# Cluster  36
# Bill Dudley & President Trump -- A New Bank War?
# Trump: Federal Reserve is loving US manufacturing troubles
# To the Former Fed Official Who Says the Fed Should Let the Economy Tank to Hurt Trump: Please Be Quiet, Sir
# Dudley 'Busted Myth' of Federal Reserve's 'Political Neutrality'
# Donald Trump & Federal Reserve: What the President Gets Right
# Varney's advice to the Federal Reserve 'Politics is not your job -- knock it off'
# Fed's Daly says her 'bias' is to run hot U.S. economy
#
# Cluster  1380
# Qualcomm targets Wi-Fi market in push to expand beyond phones
#
# Cluster  1376
# Federal judge temporarily blocks Missouri law restricting abortion
# Federal judge temporarily blocks Missouri ban on abortions at or after 8 weeks of pregnancy
# Federal judge blocks Missouri's restrictive abortion law
# Federal judge blocks Missouri's 8-week abortion ban law
# Federal judge blocks restrictive Missouri abortion law
# Judge Blocks Missouri's 8-Week Abortion Ban From Going Into Effect
# Missouri ban on abortion after eight weeks temporarily blocked by U.S. judge
# Missouri ban on abortion after eight weeks temporarily blocked by U.S. judge
# Federal judge blocks Missouri's 8-week abortion ban
# Missouri's 8-week abortion ban put on hold by federal judge
# Federal judge blocks Missouri’s 8-week abortion ban the day before it was set to take effect
# Federal Judge Blocks Missouri Abortion Law
# Missouri's 8-week abortion ban was blocked, but these anti-abortion laws are still going into effect
#
# Cluster  512
# Deal nears in talks with US: Taliban
# Afghanistan expects US-Taliban update soon as deal nears
# Taliban say near agreement on U.S. withdrawal from Afghanistan
# Taliban say near agreement on U.S. withdrawal from Afghanistan
# Taliban says near agreement on U.S. withdrawal from Afghanistan
# Taliban says agreement on U.S. troop withdrawal in Afghanistan is close
# US, Taliban closing in on agreement as top US envoy heads to Afghanistan
# Taliban says peace deal with US to end Afghan war is close
#
# Cluster  487
# Journalists’ Old Tweets Are 'Fair Game'
# New York Times updates another story, this time about the Tea Party, after liberal backlash on Twitter
#
# Cluster  827
# Tobacco giants Philip Morris and Altria in talks to reunite
# Philip Morris in merger talks with Altria; e-cigs at stake
# Tobacco merger talks: Altria, Philip Morris may reunite
# Philip Morris and Altria in merger talks as Marlboro fades and e-cigs light up
# One Big Tobacco Deal Is Enough
#
# Cluster  96
# Report: Uber and Lyft Take a Larger Share of Revenue than They Tell Drivers
# Uber makes it official: It will set up major hub in downtown Dallas by end of year
# California AB 5: Lyft and Uber drivers from across state rally in Sacramento for gig economy bill
# Lyft and Uber drivers rally in California for AB 5, the gig economy bill
#
# Cluster  301
# Cuba awaits new vision of its future
# Newspaper headlines: Andrew's accuser and no-deal Brexit 'pact'
# McDonald's offering harassment training to all US workers
# El Paso defendant's claims raise questions over gun imports
#
# Cluster  80
# Shout Out: Mark Sundberg, longtime pastor of Peace Lutheran Church in Lake Zurich who recently retired
# Barking dogs at Chevy Chase dog park divide rich and powerful
#
# Cluster  443
# Anglo American Platinum completes buyout of prospecting rights from Atlatsa
# Adani mine would be 'unviable' without $4.4bn in subsidies, report finds
#
# Cluster  1310
# When Transgender Travelers Walk Into Scanners, Invasive Searches Sometimes Wait On The Other Side
# Trans birth certificate campaign turns to other states after Victoria passes reform
# Transgender Activism: Vancouver Women-Only Rape Shelter Defunded & Vandalized
#
# Cluster  940
# Democrat Chris Murphy Becomes Second Senator Denied Russian Visa
# Russia denies visas for Ron Johnson and Chris Murphy to visit Moscow
# Sen. Chris Murphy says Russia has denied him a visa
#
# Cluster  1363
# Iran can restore oil production to pre-U.S. sanctions level within 3 days - oil minister
# Iran could restore oil output to pre-sanctions level within three days: minister
#
# Cluster  1054
# Biden health plan aims far beyond legacy of ‘Obamacare’
# Joe Biden Struggles to Remember HHS When Discussing Healthcare
# Why This Joe Biden Ad Stands Out
#
# Cluster  1061
# DC consultant's alleged affair with Ilhan Omar is front and center in divorce papers
# Divorce Filing: Wife Says Democrat Consultant Had Affair with Ilhan Omar
# Wife of D.C. political consultant alleges husband had affair with Ilhan Omar, files for divorce
# Rep. Ilhan Omar at center of Washington political consultant's divorce
# Ilhan Omar issues terse denial on allegations of affair with married DC consultant
# Ilhan Omar Denies Alleged Affair with Democrat Political Consultant
# Wife of political consultant alleges Rep. Omar had affair with her husband
# D.C. Official Files For Divorce, Alleges Her Husband Had Affair With Ilhan Omar
#
# Cluster  212
# Business Highlights
# 10 Things to Know for Today
# Business Highlights
# 10 Things to Know for Today
# Business Highlights
# How a credit card loan's fast and easy cash can cost you
# Business News, Personal Finance and Money News
# 10 Things to Know for Today
# Business Highlights
#
# Cluster  1270
# Pakistan may close airspace to India: science minister
#
# Cluster  1100
# Trump repeats misleading claim on aid to Puerto Rico as Dorian heads its way
# Trump Again Inflates Puerto Rico's Disaster Aid As Another Storm Nears
# Hurricane Trump meets Hurricane Dorian in Puerto Rico
# San Juan Mayor Slams Trump As Storm Approaches: ‘Get Out Of The Way’
# Trump slams ‘broken’ Puerto Rico ahead of Tropical Storm Dorian, accuses pols of squandering aid funds
# Trump ramps up feud with San Juan mayor ahead of Dorian
# Puerto Rico faces potential threat to life as Tropical Storm Dorian bears down
# Trump bashes Puerto Rico mayor as island braces for Dorian
# Trump news - live: President sides with 'great one' Boris Johnson, after attacking Puerto Rico mayor as Storm Dorian approaches
# Trump takes a shot at Puerto Rico as Tropical Storm Dorian nears
# Trump calls Puerto Rico 'corrupt' as island braces for Tropical Storm Dorian
# Hurricane Dorian strikes Puerto Rico still confronting recovery, Trump
#
# Cluster  257
# Mother, deputy indicted over filmed sex act involving child
# Insanity defense considered for mom accused in kids’ deaths
# C.Q. Smith focus of Pa. grand jury investigation
# Prosecutors seeking death penalty in Anthony Avalos torture case
#
# Cluster  1165
# Man's truck stolen while he robbed store across the street: Police
# A man's truck was stolen while he was robbing a store across the street, police say
#
# Cluster  442
# Trump is facing 2 emoluments lawsuits: Here’s what to know
# At the G-7, Trump Showed Again That He’s a Terrible Negotiator
# Trump Did Not Represent the U.S. at the G-7
#
# Cluster  745
# Near-total ban imposed on sending wild African elephants to zoos
# Southern African Nations Threaten to Leave Global Wildlife Pact
# Wildlife protections tightened as southern Africa protests
#
# Cluster  726
# BP to sell Alaska business to Hilcorp for $5.6 billion
# BP exits Alaska with $5.6 billion sale to Hilcorp
# BP to quit Alaska after 60 years with $5.6 billion sale to Hilcorp
#
# Cluster  334
# Ex-Kansas governor seeks primary challenger for Rep. Watkins
# Former Pence aide Nick Ayers removes self from Georgia Senate consideration
#
# Cluster  1354
# Legislature approval for Brazil's Cemig privatization may take up to six months: CEO
# Brazil's Cemig privatization plan could pass within six months: CEO
#
# Cluster  929
# CEOs claim Biden’s brother promised them 2020 candidate would help their companies
# CEOs claim Biden’s brother promised them 2020 candidate would help their companies
#
# Cluster  669
# US military shipping 'chase cars' across Atlantic to help land U-2 spy planes in UK
# The U.S. Navy’s Mine-Hunting Drone Is Ready To Go
#
# Cluster  1111
# FCC Investigates Apple, Samsung Phones After Test Finds Too Much Radiation
# Federal agents can search your phone at the US border, even if you're a US citizen. Here's how to protect your personal information.
#
# Cluster  1158
# Obama Announces New Push In Fight Against Gerrymandering
# Obama takes on partisan gerrymandering with new initiative
#
# Cluster  123
# Johnson’s schools ‘revolution’ is all about an imminent election. Here’s why it’s fake
# The Guardian view on Johnson’s schools policies: spin over substance
# Schools shake-up: the four key areas in leaked Tory proposals
# £4bn school funding boost set to be confirmed
# Tories accused of trumpeting discipline instead of investing in schools
# £3.5bn education package not enough, say school leaders
#
# Cluster  63
# YouTube to adjust UK algorithm to cut false and extremist content
# Deepfakes Are Deeply Worrying
# Study Shows How the ‘Intellectual Dark Web’ Is a Gateway to the Far Right
#
# Cluster  357
# State with ambitions as wind-energy hub seeks to lure more
# 5 East Coast governors push feds on offshore wind power
#
# Cluster  980
# Florida police blame staff's neglect for post-hurricane nursing home deaths
# Police expect case of heat-related deaths at Florida nursing home to yield more arrests
#
# Cluster  205
# Fresenius Medical Care appoints Takeda executive Helen Giza as CFO
# BRIEF-Straumann Makes Appointments To Executive Management
# BRIEF-Givaudan Mostly Interested In Bolt-On Acquisitions -CFO
#
# Cluster  1
# Former Google engineer charged with trade secrets theft
# U.S. charges former Alphabet engineer with stealing self-driving car secrets
# Ex-Google engineer charged with stealing company's trade secrets for driverless cars
# Ex-Uber and Waymo engineer charged with trade secrets theft
# Former Google self-driving car engineer charged with theft of trade secrets
# Ex-Google engineer charged with theft of autonomous car secrets
# Timeline: Autonomous car pioneer Levandowski faces criminal charges of stealing from Alphabet
# U.S. charges ex-Alphabet engineer with stealing self-driving car secrets
# Ex-Google engineer charged with taking stolen self-driving secrets to Uber
# Explainer: Ex-Google engineer faces severe penalties in self-driving trade secrets case
# BRIEF-Ex-Google engineer Levandowski pleads not guilty to stealing trade secrets
# Ex-Google engineer indicted for stealing self-driving car secrets, pleads not guilty
#
# Cluster  330
# Canadian court grants new trial to two men charged with attempted train bombing
# Bangladeshi Man Pleads Guilty to Smuggling Countrymen into U.S.
#
# Cluster  1236
# Jair Bolsonaro demands Emmanuel Macron withdraw 'insults' over fires
# Bolsonaro to Macron: Stop Hurling Insults at Me
# Macron must take back 'insults' for Brazil to accept G7 Amazon aid: Bolsonaro
# Brazilian governors say now is 'not the moment to turn down money' as Amazon wildfires rage
# Brazil's president said he would accept $20 million from the G7 to tackle the Amazon fires, but only if Emmanuel Macron apologizes for calling him 'extraordinarily rude'
#
# Cluster  755
# U.S. moves FEMA, Coast Guard money to fund border programs
# Morning News Brief
# News Brief: Border Enforcement Funds, Tropical Storm, E-Cigarette Lawsuit
# As hurricane season ramps up, millions in FEMA and Coast Guard funds to be moved to boost southern border policies
#
# Cluster  568
# Fresh £10m Brexit fund for English ports 'tiny amount of money'
# Banks have done all Brexit preparations, ECB's Enria tells Finnish TV
# UK and Irish businesses want €1bn to withstand 'no-deal Brexit shock'
#
# Cluster  338
# SEC fines audit firm RSM $950,000 to settle independence violation claim
# Third Point, U.S. settle over antitrust filing in DowDuPont stake
# SEC fines Texas-based firm for offering illegal tokens, unregistered exchange
# SEC fines Juniper Networks more than $11.7 million to settle internal control violations
#
# Cluster  525
# GRAPHIC: 33 Migrants Found Dead in One Texas County This Year
# Border Patrol agents find at least 3 bodies along southern border, officials say
# Border Patrol Rescues Mexican Woman Lost in Texas Desert, 2nd Found Dead
#
# Cluster  73
# Scaramucci: Officials should consider removing Trump through 25th Amendment
# Heckler Says Pelosi's Inaction 'Will Make Trump’s Re-election More Likely'
# Ingraham: Never Trumpers 'clinging to their fantasy'
#
# Cluster  215
# Fire Engulfs Philadelphia Church: One Person Hospitalized
# Three-alarm fire rips through 115-year-old Philadelphia church
# Video: Fire Erupts at Massive Philadelphia Church
# Having fully contained the Eagle Rock fire, firefighters now focus on cleanup
#
# Cluster  1053
# Indonesia's plan to move its capital could be bad for democracy.
# Indonesia will relocate capital from sinking Jakarta to Borneo
# Indonesia pledges $40 billion to modernize Jakarta ahead of new capital: minister
# Capital flight: Indonesian move could prompt new environment crisis
#
# Cluster  561
# ‘Depraved human being’: Jeffrey Epstein accusers voice their anguish in court
# 'Coward': Accusers rip Jeffrey Epstein in court hearing Tuesday
# Jeffrey Epstein Accusers Get Their Day In Court After His Death
# 'Eats away at my soul': Epstein accusers testify weeks after his suicide
# Epstein accusers detail sexual abuse claims in emotional court hearing
# ‘Coward’: Epstein accusers pour out their anger in court
#
# Cluster  626
# GOP senator says chances are "better than they have ever looked" for gun control measure
# Sen. Pat Toomey: Odds of Passing Gun Control Better Than Ever
#
# Cluster  534
# Mexico's truck makers delay investment amid doubts on new clean diesel rules
# Mexico pipeline deal positive for infrastructure firms' credit ratings: Moody's
#
# Cluster  384
# Wayne Swan warns climate change will reshape politics as much as 9/11
# A record hot summer burned the first fruit of my apple tree - and left a bad taste in my mouth
# Overlooked in Democrats’ Climate Debate: Any Plan Must Get Past Republicans
# Are Republicans ready to deal with climate change?
#
# Cluster  134
# Great Barrier Reef expert panel says Peter Ridd misrepresenting science
# CORRECTED-(OFFICIAL)-BRIEF-Bio-Rad Posts Q2 EPS Of $19.86 (Aug. 1)
#
# Cluster  1021
# Australian universities to work with security agencies to combat foreign interference
# Australia moves to protect universities from foreign interference
# Australia tries to curb foreign interference at universities
#
# Cluster  494
# Former NSW Labor staffer never saw cash donations as large as $5,000, Icac hears
# Man 'dumbfounded' by invoice for $5,000 Labor donation he never made, Icac told
# Australian who says he invented bitcoin ordered to hand over up to $5bn
#
# Cluster  255
# Australia should delay free trade deal with Hong Kong, ACTU says
# Trump’s Trade War Washes Up on Australia’s Shore
# Australia managed to survive the global recession - but all that good work has been wasted
# Coalition must give up dream of budget surplus if China crashes, report says
# Western Australia loosens emission reduction requirements for new major projects
#
# Cluster  1412
# Raising Australia's refugee intake would boost economy by billions, Oxfam says
# Australia's sovereign fund posts double-digit returns on emerging markets bets
#
# Cluster  624
# Greg Gutfeld: Biden needs to outpace Warren, Sanders before one progressive drops out
# Reports: Activists Say Warren Has Most Momentum in Early States
# Warren outpaces Sanders in new 2020 polls, Biden retains front-runner position
# Biden leads Democrats as Warren climbs, Sanders slips
# Biden, Warren and Sanders still at the top
# Elizabeth Warren is the only candidate to consistently rise in the polls. That could make her the candidate to beat in the 2020 primaries.
#
# Cluster  1312
# Spanish warship picks up 15 migrants to fire political shot
# Spanish warship picks up 15 migrants to fire political shot
#
# Cluster  1210
# Christopher Allen's family wants justice after his death in South Sudan
# Kenneth Bialkin, Lawyer and Jewish Leader, Dies at 89
#
# Cluster  30
# Four years in prison for man who trafficked gun used in slaying of 9-year-old Tyshawn Lee
# California gang members get decades in prison for murdering 19-year-old Marine
# West Virginia man sentenced for stealing firearms from ATF
# California man exonerated in stabbing death after 28 years in prison
#
# Cluster  433
# UPDATE 1-Canadian province Alberta warns of spending curbs ahead
# Canada's ruling Liberals to target wireless bills in election: sources
#
# Cluster  1411
# Can power napping solve electric car charging challenge?
#
# Cluster  240
# Trump’s approval is way down in key states - as long as you compare it to that one time he was popular 31 months ago
# Two Polling Methods, Two Views of Trump’s Re-election Chances
# Americans concerned about legitimacy of 2020 election before it even happens: poll
# Poll: Both Democrats and Republicans doubtful of 2020 election outcome
# Trump’s worst 2020 poll yet
#
# Cluster  302
# PRECIOUS-Gold jumps 1% on recession fears; silver breaches $18/oz mark
# PRECIOUS-Gold holds near six-year high on economic gloom
# PRECIOUS-Gold dips, but near 6-year high on rate cut hopes, trade fears
# PRECIOUS-Gold hovers near 6-year peak on slowdown fears, trade jitters
# PRECIOUS-Gold holds near 6-year peak on slowdown fears, trade jitters
# PRECIOUS-Gold eases as investors book profits, dollar firms
# PRECIOUS-Gold prices tick up on recession fears, trade uncertainty
# PRECIOUS-Gold prices edge higher on recession worries, trade uncertainty
# PRECIOUS-Gold steadies near six-year high, silver jumps as growth risks persist
# PRECIOUS-Gold prices inch down on positive signs for trade talks
#
# Cluster  1321
# Six women seeking Colorado Senate seat ask DSCC to reconsider endorsement of Hickenlooper
# Colorado Senate & John Hickenlooper: Democratic Women Ask DSCC to Rescind Endorsement
#
# Cluster  542
# Column: Why I appreciate presidential candidate Joe Walsh - for now
# Herman Cain: Trump GOP opponent Joe Walsh, conservative columnist Jennifer Rubin just seeking 'publicity'
# Trump bashes GOP primary challengers including Joe Walsh, Bill Weld
# Weld says fellow GOP primary underdog Walsh 'almost as vulgar’ as Trump, but won't judge
# New Trump 2020 challenger: 'Nothing special about me,' I'll get in Trump's face every day
#
# Cluster  963
# College Board abandoning SAT 'adversity score' after criticism
# College Board Abandons Plan for SAT Adversity Scores
# College Board abandons SAT 'adversity score' for a new tool
# College Board Nixes Plan for SAT ‘Adversity Scores’
#
# Cluster  1282
# Boris Johnson's words on UK battery sector 'not matched by action'
# Energy companies frustrated at slow progress on taxpayer underwriting deals
#
# Cluster  264
# Jewish Brooklyn man violently attacked in possible hate crime
# 48 Years Later, a Cold Case Mystery: Who Killed Officer Bolden?
# Homeless man burned to death in skid row area
#
# Cluster  1292
# Fed rejects call to deny Trump rate cuts; Trump keeps up pressure
# New York Fed among six banks voting in July for no change in discount rate
# Fed divided on policy, discount rate votes show
#
# Cluster  535
# School: Guard who wounded student was supposed to be unarmed
# 2 detained after reports of shots fired near Eastvale school
# St. Louis shaken after the shooting deaths of at least 12 children since April
# 2 taken to hospital with gunshot wounds from office building
# Parents, county clash in court over Parkland shootings
#
# Cluster  322
# Lori Loughlin and husband to stick with joint counsel to fight charges in 'Varsity Blues' college entrance scam
# New York prosecutors raise victims' hopes that Ghislaine Maxwell could face charges
#
# Cluster  604
# Mormon church clarifies gun policy: No lethal weapons on church property
# New Zealand Vowed to Listen to Muslims After Christchurch. It’s Failing, They Say.
#
# Cluster  777
# 3 European nations condemn North Korea’s missile launches
# 3 European nations condemn North Korea’s missile launches
#
# Cluster  1110
# UK advert for post-Brexit EU citizen scheme ruled misleading
# New rules require ID check
#
# Cluster  495
# Fuzzy math: Democrats spend big to draw small-dollar donors
# Hollywood Executive's D.C. Donations Under Scrutiny After Arrest
# Los Angeles has lined up record-cheap solar power. But there's a problem
#
# Cluster  137
# 'People Want to Work'
# Warren Undercuts Populist Agenda with Donor Class Immigration Plan
# Bernie Sanders Hails Volunteer Army As Advantage Over Rivals
#
# Cluster  131
# Kenya Begins Exporting Oil, Prompting Revenue-Sharing Demands
# Exclusive: Aramco Trading sells first U.S. West Texas Light crude to South Korea's Hyundai - sources
# Russian state-controlled grain trader looks to sell grain to Egypt
#
# Cluster  530
# Wikipedia Editors Attack China Critic 'Epoch Times' After NBC Hit Piece
# Pro-China Propaganda Site Caters to Chinese Students in America
# Washington Post publishes special advertising section pushing 'propaganda' for communist China
#
# Cluster  1172
# Macron’s G-7 performance arms him for likely troubles ahead
# Emmanuel Macron Clears a Low Bar at the G7
#
# Cluster  369
# Boeing faces its first lawsuit from a 737 Max customer
# Exclusive: Boeing CEO eyes major aircraft order under any U.S.-China trade deal
# Exclusive: Boeing CEO eyes major aircraft order under any U.S.-China trade deal
#
# Cluster  1069
# Hundreds of parts from endangered birds reportedly found for sale via Facebook
# Thailand to acquire 120 U.S. armored vehicles
#
# Cluster  975
# Would Nigel Farage be Hitler or Stalin in Brexit 'non-aggression pact'?
# Boris Johnson should have the guts to kill HS2
# Did Boris Just Commit Brexit Suicide For the Love of Farage?
#
# Cluster  1283
# Lowe’s exec apologizes for Hispanic ‘small hands’ comment
# Lowe's VP Touts Power Drill As Perfect For 'Hispanic Pros With Smaller Hands'
#
# Cluster  492
# Woman awarded $3.2 million in revenge-porn lawsuit against Army officer ex-husband and his girlfriend
# Florida city, under fire for imposing massive fines on homeowners, drops lawsuit against woman
#
# Cluster  392
# Jeffrey Epstein's death: Democratic Women's Caucus asks for House investigation
# Only 33% of Americans believe that Jeffrey Epstein actually died by suicide
# Jeffrey Epstein injuries ‘far more consistent with murder than suicide’, lawyer says
# A growing number of Americans doubt that Jeffrey Epstein died by suicide. Here's a guide to the conspiracy theories about his death, and why they're not backed by evidence.
#
# Cluster  677
# Sting Condemns Brazil’s Handling of Amazon Fires: ‘We Will All Suffer the Consequences’
# As Amazon Fires Rage, Brazil’s Government Employees Warn of ‘Collapse’ of Protection System
# Experts explain how the Brazilian wildfires became so devastating and what can be done to save the rain forest
# Exclusive: As fires race through Amazon, Brazil's Bolsonaro weakens environment agency
# Amazon fires: Forest loss challenges Paris climate ambition
# ‘Worst of wildfires still to come’ despite Brazil claiming crisis is under control
# How California Can Help Save Brazil’s Burning Rainforests
#
# Cluster  103
# New leech species with three jaws and 59 teeth found in swamps outside Washington
# New manufacturing jobs announced in Shenandoah County
# Maryland, Virginia among 22 states reporting incidents of vaping-related illness
#
# Cluster  476
# Trump admin pulling millions from FEMA disaster relief to send to southern border
# Trump administration moves millions from FEMA disaster relief to fund ICE
# Trump Administration Sending Millions From Disaster Relief Fund To Southern Border
# Trump administration taps disaster, cyber funds to cover immigration
# Trump administration to use millions in disaster aid for migrant detention centers
# Trump administration to divert FEMA funds for migrant detention and border enforcement
# Trump administration will divert disaster relief funds to U.S.-Mexico border enforcement, prompting outcry from Democrats
# Trump Administration to Reallocate Hurricane Relief Funds to Border Security
# Trump Admin to Reallocate Hurricane Relief Funds to Border Security
#
# Cluster  900
# Susan Collins says she may lose votes over Kavanaugh support
# ‘Rev it up’: Back at home, Klobuchar is told to get tough
# John Kasich Doesn't See Path to Beat Trump ‘Right Now'
#
# Cluster  359
# Lindsey Graham: 'God bless Donald Trump' for confronting China, which 'destroyed' South Carolina textile industry
# Free Beacon editor in chief: Trump is asking China to 'pay a price' it can't afford
# Trump to blame for Columbia’s unfixed 2015 flood damages: Mayor
#
# Cluster  734
# 'Suspicious' deaths at West Virginia VA hospital under investigation
# VA investigating patient deaths at West Virginia hospital
# Deaths at VA medical center in West Virginia are being investigated
# VA investigating patient deaths at West Virginia hospital
# U.S. authorities investigate deaths at veterans hospital
# U.S. authorities investigate as many as 11 deaths at veterans hospital
# At least 9 deaths at VA medical center in West Virginia under investigation
#
# Cluster  291
# U.S. hopes South Korea and Japan can rebuild ties from 'rock bottom'
# Wildlife thrives among the land mines along Korea’s DMZ. But for how long?
# Japan and South Korea Feud, but Breaking Up Is Hard
# North Korea building warheads to penetrate Japan defenses, Tokyo claims
#
# Cluster  1202
# Authorities investigating string of 10 patient deaths
# VA investigating several patient deaths at West Virginia hospital
# Second Death At West Virginia VA Hospital Ruled As Homicide
#
# Cluster  164
# Suspect fled to Mexico after hit-and-run left one person dead, police say
# Libya Buys Buses from China Despite Not Having a Public Transit System
#
# Cluster  1242
# France postpones announcement on its EU commissioner candidate
# France can reduce unemployment to 7% by 2022: labor minister
#
# Cluster  993
# Opioid drugmaker Purdue Pharma offers $10-12 billion to settle opioid claims: NBC News
# Purdue Pharma offers $10 billion-$12 billion to settle opioid claims: NBC
# Purdue Pharma in discussion on $10 billion-$12 billion offer to settle opioid claims: sources
# Purdue Pharma in discussion on $10 billion-$12 billion offer to settle opioid claims: sources
# Purdue Pharma in discussion on $10 billion-$12 billion offer to settle opioid lawsuits: sources
# OxyContin maker Purdue Pharma, Sackler family, offer up to $12B to settle opioid suits
# Sackler family backs $11.5-billion Purdue opioid settlement
#
# Cluster  627
# Exclusive: Texas storage operator jumps into race to produce low-sulfur marine fuels
# U.S. weekly crude production hits record 12.5 million bpd: EIA
#
# Cluster  329
# A Q&A With the Man Who Called Bret Stephens a Bedbug
# Trump mocks NYT's Bret Stephens: My resort doesn't have 'bedbugs,' but he's 'loaded up with them!'
# 'Tough guy!': Trump mocks Bret Stephens over bedbug controversy
# Trump mocks New York Times' Bret Stephens for bedbug reaction
# 'Tough guy!': Trump mocks NYT columnist Bret Stephens for bedbug reaction
# Donald Trump Ridicules 'Bedbug' NYT Columnist Bret Stephens
#
# Cluster  1188
# US-Mexico border town occupied by drugs, crime, cartel
# The U.S. Border Patrol Has a Drug Dog Named Adolf-And Has No Plans to Change Its Name
#
# Cluster  1229
# Feds accuse county of racial bias in hiring police officers
# Baltimore County police have been using racially discriminatory hiring practices, the Justice Department says
# Justice Department accuses Baltimore County of racial bias in police hiring
#
# Cluster  1041
# Trump suggested using bombs to fight hurricanes. These 4 graphics show why that would never work.
# A Brief History of Attempts to Attack the Weather
# Bugged, storming: Trump tweets tirade on bedbugs, nuking hurricanes
# Trump Seems Seriously Touchy About The Whole Nuking Hurricanes Story
#
# Cluster  466
# Vice President Mike Pence dismisses talk of rivalry with Nikki Haley
# Pence, in visit to Iceland, to discuss 'incursions' into Arctic Circle by China, Russia: official
#
# Cluster  630
# Vast fires sweep across Bolivia as well as Brazil
# Brazil's neighbors call for meeting and Amazon pact as fires rage
# Focus on Brazil's Amazon fires, but a massive inferno rages next door in Bolivia
# Amazon Fires 'Under the Average of the Past Few Years'
# Amazon burning: Brazil reports highest forest fires since 2010
# Brazilian indigenous speak out as Amazon fires rage
# Brazil’s Neighbors Are Also Burning and Poisoning the Amazon
# Brazil soy plantings in Amazon fire hotspots is minimal: industry group
#
# Cluster  380
# Contigo Kids Cleanable Water Bottles recalled due to choking hazard
# Toyota recalls air bags that may not inflate properly
#
# Cluster  1355
# Giant exoplanet is 'like a wrecking ball,' astronomers say
#
# Cluster  364
# Biden aide says gaffes are 'part of his charm'
# Tammy Bruce: 'Opportunist' media's adoration of Biden diminishing after gaffes
# Hannity on the allegations that Biden's family profited from his time as VP: 'Beyond sketchy'
# Mika Brzezinski calls out Obama while defending Biden: 'Did he really govern?'
#
# Cluster  605
# Trump to tap FEMA account to step up migrant deportations, House Dems say no way
# Trump’s bank has tax records Congress is seeking in subpoenas targeting the president’s finances
# Democrats Insist They Haven't Been Wasting Time On Trump's Tax Returns
#
# Cluster  997
# In a rare move, a Calexico Border Patrol agent has resigned after pleading guilty to assaulting a migrant
# Border Patrol Agent Pleads Guilty to Hitting Man in Face
# Border Patrol agent pleads guilty to hitting migrant in face
#
# Cluster  957
# Wireless carriers slow streaming video content even in off-peak hours
# Eight Charged with Running Pirate Streaming Sites with Libraries Larger than Netflix
#
# Cluster  89
# Lincolnwood gives preliminary nod to synagogue
# After agreement, District 69 officials express support for downtown Skokie TIF district
#
# Cluster  1325
# How Uber’s quest for self-driving tech led to criminal case
# Drug dealers offered driving lessons instead of prison in new police scheme
#
# Cluster  199
# Opioid marketing and the First Amendment: Oklahoma judge rejects J&J defenses
# Column: Johnson & Johnson got hit for a $572-million opioid verdict. Why did its stock go up?
# IN BRIEF: Judge rejects bid to bar opioid epidemic plaintiffs' experts
# Johnson & Johnson Was Ordered to Pay $572 Million for Its Role in the Opioid Crisis. With Similar Lawsuits Across the Country, That Could Be Just the Beginning
# I’m A Former Opioid Addict. Here’s What The Johnson & Johnson Ruling Gets Wrong.
# US opioid crisis: experts say payouts from drug makers ‘highly questionable’
# Drugmakers' liability for opioid crisis could reach $150 billion
# Drug makers conspired to worsen the opioid crisis. They have blood on their hands
#
# Cluster  1104
# Pritzker signs stripped-down corporate diversity bill, calls it a ‘big first step’
# Illinois Passes New Law Requiring LGBTQ Classes in Middle School
#
# Cluster  1227
# Michigan man accused of killing wife by spiking cereal with heroin
# Michigan Man Accused of Murdering Wife by Putting Lethal Dose of Heroin in Her Cereal
# Michigan man accused of putting fatal dose of heroin in his wife's cereal
# Michigan man charged with murder for spiking wife's cereal with heroin
#
# Cluster  743
# Chinese State Media Cites Taylor Swift in Attack on Donald Trump
# Taylor Swift's Equality Act Push Gets Frosty Response From Trump Administration
# Kellyanne Conway Accidentally Torches Trump With Painful Singing Attempt
# Franklin Graham slams Taylor Swift's Equality Act support as ‘crushing threat to religious liberty’
# Kellyanne Conway responds to Taylor Swift with her lyrics: ‘You need to calm down'
# The White House Responds to Taylor Swift’s Criticism at the VMAs
# "You need to calm down": Kellyanne Conway responds to Taylor Swift with the singer's own lyrics
# Kellyanne Conway Sings Taylor Swift's 'Calm Down,' Disses Her for 'Losing Handily' to Trump
# Kellyanne Conway sings Taylor Swift song in rebuke of Equality Act advocacy
#
# Cluster  555
# Upcoming polls give Steyer shot at Democratic debate, could push it to two nights
# Julian Castro, Tom Steyer to DNC: Nevada Polls Needed for Debate Qualification
# Democratic debate appears set for 10 candidates after Tom Steyer fails to qualify
# Tom Steyer’s mega-millions debate gambit flops
# Why Tom Steyer couldn't buy his way onto the debate stage
#
# Cluster  794
# MSNBC Host: Women Politicians More Trustworthy Than Men
# The Republican Party’s White Women Problem
# Why are so many men are afraid to interact with women at work?
#
# Cluster  514
# Study: Black students unfairly labeled with learning disorders
# Blind University of Glasgow student 'faced reading list discrimination'
# Naplan test results 2019: year 7 and 9 writing skills have declined
#
# Cluster  660
# Officials conceal KKK letters welded on building in Arkansas
# Video shows police drawing guns, handcuffing black man in his own home after false alarm
#
# Cluster  565
# U.S. State Department OKs missile sale to Japan worth $3.3 billion
# UPDATE 1-Ted Baker seeks to propel growth in Japan with license deal
#
# Cluster  253
# U.S. Seeks to Work with Australia to Break China’s Hold on Rare Earths
# 'Space Mirrors,' Higher Ground,
# Chinese Rocket Tech Just 6 Years Behind SpaceX -- And Gaining
#
# Cluster  493
# Presumed nominee for Montgomery County police chief pulls name from consideration
# Regina Romero wins Democratic primary in Tucson, poised to be city's first woman, first Latina mayor
#
# Cluster  701
# Barr books holiday party at Trump hotel, stoking ethics concerns
# William Barr Books $30,000 Party At Trump Hotel: Report
# Attorney General William Barr to host holiday party at Trump Hotel
# Barr Plans to Throw $30,000 Holiday Party at the Trump Hotel in Washington
#
# Cluster  867
# AOC mocks Trump over tweet calling Electoral College a 'disaster': 'I agree!'
# Candidates hope to replicate Ocasio-Cortez's tactics across the country
# Trump campaign attacks AOC, Democrats: 'This is our country, not theirs'
# Alexandria Ocasio-Cortez Has A Blunt Correction For Trump’s Puerto Rico Boast
#
# Cluster  270
# Kellyanne Conway: Trump's committed to China trade negotiations; doubters haven't been 'paying attention'
# Navigating the trade war: How to invest during turmoil
# Trade insiders say Trump’s botching chances of a China deal
# Experts Say President Trump Is Right to Play Hardball with China
# The art of a bad deal: A negotiations expert breaks down the everyday lessons we can learn from Trump's messy trade war with China
#
# Cluster  872
# Deutsche Bank reveals it has access to tax returns related to Trump congressional investigation
# Deutsche Bank says records sought by Democrats include tax returns
# Deutsche Bank says records sought in Trump congressional probe include tax returns
# Deutsche Bank acknowledges it has tax returns tied to Trump sought by House committees
# Deutsche Bank has tax returns sought in Congressional probe
# The Trump Secrets Hiding Inside Deutsche Bank
# Deutsche Bank has Trump-related tax returns sought by House Democrats
# Deutsche Bank has tax returns sought in Congressional probe
# Here Are All The Ways Democrats Are Trying To Get Trump's Tax Returns
#
# Cluster  1119
# PragerU Lawyer: Google and YouTube Need 'Viewpoint Neutral' Rules that 'Apply Equally to All'
# PragerU exec blasts YouTube's 'laughable' claim it's politically neutral
#
# Cluster  1268
# OxyContin maker Purdue Pharma offers up to $12B deal, report says
# OxyContin maker Purdue Pharma reportedly offering opioid settlement up to $12B
# OxyContin maker, government attorneys in settlement talks
# OxyContin maker, government attorneys in settlement talks
# OxyContin maker negotiating settlement worth a reported $12B
#
# Cluster  429
# Far-Left Twitter 'Trust and Safety Council' Complains Execs Are Ignoring Them
# Big Tech 'Abused' Section 230 to Censor Conservatives
# Social workers: 'I had a parent screaming foul names at me'
# Tech firms struggle to police content while avoiding bias
#
# Cluster  8
# How Trump got under the media’s thin skin
# Sean Spicer: Trump critics should learn from his supporters instead of demonizing them
# Trump’s Corruption Is Now More Brazen Than Ever
# Trump Adrift without Suitable Political Enemy
# Some of Trump's Critics Are as Trigger-Happy as He Is
#
# Cluster  1396
# California twins split up to attend different US military academies
#
# Cluster  641
# 5 years in, Washington considers overhaul of pot regulation
# 5 years in, Washington considers overhaul of pot regulation
#
# Cluster  1073
# Russia denies visas to two U.S. senators, amid G7 tensions
# Since Relations Soured, Getting A U.S. Visa Has Been Tough For Russians
# Since Relations Soured, Getting A U.S. Visa Has Been Tough For Russians
# Russia: US senators claiming visa ban are on blacklist
#
# Cluster  1029
# Judge orders men who lied about being veterans to write names of those killed in Iraq, Afghanistan
# Montana Men Must Hold ‘I Stole Valor’ Signs for Misrepresenting Military Service
# Montana Men Who Lied About Military Service Ordered To Wear 'I Am A Liar' Signs
# 2 men who faked military service are ordered to write names of 6,700 Americans killed in action
#
# Cluster  840
# Beto O'Rourke Ejects Breitbart News Reporter from Event at Historically Black College
# Trump Campaign,Media, GOP Respond to Beto Ejecting Breitbart Reporter
# O'Rourke campaign blasts Breitbart after ejecting reporter
# Beto O'Rourke boots Breitbart News writer out of event at HBCU
# O'Rourke campaign blasts Breitbart after ejecting reporter
# Breitbart Won't Be Banned from More Events
# O’Rourke campaign ejects Breitbart reporter from speech
# O’Rourke campaign ejects Breitbart reporter from speech
#
# Cluster  431
# Explosion hits Gaza motorcycle, two dead: officials
# Explosions hit Gaza police checkpoints, two dead: officials
# Deadly Explosions Target Hamas Police Checkpoints in Gaza
# Explosions hit Gaza police checkpoints, three dead: officials
# Three killed in Gaza after explosions at two police checkpoints
# Gazans bury policemen killed in rare attacks within strip
# Hamas says Gaza blasts that killed three policemen were suicide bombings
# Three Hamas policemen killed in rare attacks with Gaza in 'state of alert'
# Gaza under alert after suicide bombings kill three police officers
# Hamas Arrests 10 Suspects in Gaza Suicide Bombings
#
# Cluster  24
# There are no male northern white rhinos left. Can IVF save the species?
# Why More Dogs and Cats Are Making It Out of Shelters Alive
# U.N. agency urges U.S. to reinstate funds to protect women
#
# Cluster  1383
# Rep. Steve King Laughingly Says Muslims Should Be Forced To Eat Pork
# Rep. Steve King jokes about imprisoned Muslims being forced to eat pork in China
#
# Cluster  1033
# Biden: Racism in US is institutional, ‘white man’s problem’
# Biden: Racism in U.S. a ‘white man’s problem’
# Biden: Racism in US is institutional, ‘white man’s problem’
# Racism is a 'white man's problem'
# Joe Biden: Racism is a 'white man's problem' that is institutional in the U.S.
#
# Cluster  179
# Thailand May Be First in Southeast Asia to Allow Same-Sex Unions
# Appeal to stop gay marriage opens in Cayman Islands
# ...
# Molotov cocktail toss in Florida is latest attack against DHS facility: report
# Woman tosses Molotov cocktail into Florida citizenship office
# Suspect Tosses Molotov Cocktail into Florida DHS Facility
# Molotov cocktail thrown into US Citizenship and Immigration office
#
# Cluster  1167
# 'I think almost anybody' could beat Donald Trump in 2020
# 'Almost Anybody' Could Beat Trump
#
# Cluster  416
# With substitute teachers in high demand, Montgomery County eases requirements
# More than 54,000 citations issued in Maryland for passing school buses
#
# Cluster  1406
# 6-year-old girl fights to get female army soldiers added to the toy military
#
# Cluster  132
# Babies in the Beehive: the man behind New Zealand's child-friendly parliament
# Bricka Bracka Firecracka Sis Boom Bah!
#
# Cluster  1418
# Sajid Javid ‘poised to break government limit on borrowing’
# All eyes will be on Javid as Johnson’s fiscal plans are unveiled
# Javid defends settled status scheme in response to criticism
#
# Cluster  280
# No ICE enforcement operations in affected areas
# ICE Ignores State Pardons In Connecticut
#
# Cluster  31
# Exclusive: Messaging app Telegram moves to protect identity of Hong Kong protesters
# What You Need To Know : NPR
#
# Cluster  1264
# U.S. blacklists Iranian oil tanker Adrian Darya, sanctions captain
# U.S. engages in threats to stop Iran oil sales to traditional clients - Zarif
# U.S. engages in threats to stop Iran oil sales to traditional clients: Zarif
#
# Cluster  932
# Riot police out in Glasgow as Irish unity march sparks disorder
# Two arrested after riot following Irish unity march in Glasgow
#
# Cluster  1063
# DEA makes nearly 300 arrests in massive Florida crackdown
# DEA crackdown across Florida nets 300 arrests, heroin, opioid pills and yacht
#
# Cluster  819
# Illinois governor pardons crime of deported Army vet
# Gov. J.B. Pritzker pardons deported Army veteran of felony drug conviction
# Illinois governor pardons Army vet deported to Mexico
#
# Cluster  1382
# Costa Mesa council to take another look at the Plant, a long-discussed commercial-residential project
#
# Cluster  1276
# Lost Nuclear Material Resurfaces In Maryland : NPR
#
# Cluster  1058
# Tens of Thousands Take to Streets to Protest Boris Johnson Maneuver in Parliament
# Boris Johnson's suspension of Parliament sparks Brexit protests
# Crowds gather in UK cities to protest Johnson’s Brexit plans
# Parliament’s suspension before Brexit protested across UK
# Thousands protest British PM Johnson's move to suspend parliament
# For Brexit protesters, a larger issue is at stake: democracy
# Parliament's suspension before Brexit is protested across Britain
#
# Cluster  500
# Death Toll in West Texas Shooting Climbs to 7
# Dozens injured by shootings in Texas towns, authorities say; 2 suspects sought
# At least 2 dead, up to 20 injured in West Texas shooting, mayor says; 1 suspect in custody
# At least 5 dead, more than 20 injured in West Texas shooting, official says; suspect dead
# At least 21 shot, 5 killed in West Texas shooting, official says; suspect dead
# At least 24 shot, 5 killed in West Texas rampage, official says; suspect dead
# 2 Dead and Up to 20 Injured in Shootings in Midland, Tex., Officials Say
# Odessa police chief: 21 shot, 5 killed in Texas shooting
# Massacre in Odessa, Texas, leaves total of at least 35 people killed in mass shootings in August
# 5 dead, 21 injured by shooter in Odessa, Texas, police say
# 5 dead, 21 injured after motorist opens fire in Odessa, Texas
# Multiple Injured In Shootings In Western Texas
# Two killed, around 20 injured in Texas shooting: media
# Five dead and 21 injured in Texas shooting, police say
# Five killed, including shooter, around 21 injured in Texas shooting: police, media
# 5 killed, 21 injured in a mass shooting in Odessa, Texas
# Odessa police chief: 21 shot, 5 killed in Texas shooting
#
# Cluster  1070
# Should Your Avatar's Skin Match Yours?
#
# Cluster  427
# Police Confirm 5 dead In Midland, Odessa Area : NPR
# Shooter In Odessa, Texas, Firing At Random People, Police Say : NPR
# Gunman at large in hijacked mail truck, 'shooting at random people'
# Police: 'Multiple gunshot victims' in Texas shootings
# Police say “multiple gunshot victims” after suspect hijacked mail truck in Odessa, Texas, and is shooting at random
# Texas police say two gunmen at large after shooting at Odessa Home Depot
# 3 Officers Reportedly Shot in Midland-Odessa Shooting Incidents
# Police looking for two suspects
# Police: “Multiple gunshot victims” from Texas shootings
#
# Cluster  306
# Day Of Peaceful Demonstrations In Hong Kong Ends Violently
# Live: Hong Kong's 13th straight weekend of unrest
# Live: Hong Kong's 13th straight weekend of unrest
# Live: Hong Kong's 13th straight weekend of unrest
# Reporting on Hong Kong: 'What will happen to this wonderful city?'
# Hong Kong burns during another weekend of violence
# Hong Kong: ‘Revolution is war, and no war is without bloodshed’
#
# Cluster  920
# North Korea Says Hope of More U.S. Talks Is ‘Disappearing’
# North Korea berates Pompeo, says hopes for talks fading
# North Korea berates Pompeo, says hopes for talks fading
# North Korea berates Pompeo, says hopes for talks fading
#
# Cluster  420
# After Cancer Treatment, Ginsburg Says She'll Be Ready For High Court's October Term
# Ruth Bader Ginsburg: I'm 'alive and on my way to being very well'
# Justice Ginsburg: 'I am on my way to being very well'
# U.S. Justice Ginsburg says she is on her way to 'being very well'
# Justice Ginsburg reports she’s ‘very well’ following cancer
# Justice Ginsburg reports she's 'very well' following cancer
# Ruth Bader Ginsburg: 'I'm on the way to being very well' after cancer treatment
# I'm Alive and 'on My Way to Being Very Well' After Cancer Scares
# Justice Ginsburg reports she's on way to 'well' after cancer
#
# Cluster  1126
# 51 People Died in Mass Shootings in August Alone in the U.S.
# Some of the most recent deadly US mass shootings
# Some of the most recent deadly US mass shootings
#
# Cluster  740
# South Korean Lawmakers Visit Disputed Islets Claimed by Japan
# South Korean lawmakers visit disputed islets as Japan tensions mount
#
# Cluster  176
# Pompeo says U.S. believes Iranian oil tanker headed to Syria
# UAE firms scout trade at Syria fair, defying U.S. pressure
# US blacklists Iranian tanker Mike Pompeo says is heading to Syria
#
# Cluster  1285
# Cuba unveils tighter rules on cooperatives in clampdown on non-state sector
#
# Cluster  546
# Muir Elementary School’s new principal enjoys homecoming
# Fresno cheerleader's blackface video raises ghosts of racist past
#
# Cluster  972
# Torfaen mum feared losing autistic daughter over rent debt
# 1.8 million SC residents live in shelter poverty study says
#
# Cluster  67
# Burbank officials look to fill vacant city positions
# Hudson's Bay to close Dutch stores -newspaper
#
# Cluster  1309
# Arizona State students from China detained at LAX, denied entry to US
# 9 Arizona State students from China detained at LA airport, denied admission to U.S.
#
# Cluster  877
# Newsom strikes deal in California to cap rent increases
# California governor announces deal to cap rising rent prices
# California governor announces deal to cap rising rent prices
#
# Cluster  1367
# RFK assassin Sirhan Sirhan stable after prison stabbing
# Sirhan Sirhan is reportedly stabbed at prison in San Diego
# Robert F. Kennedy assassin Sirhan Sirhan stabbed in prison
# Convicted RFK assassin Sirhan Sirhan stabbed in California prison: reports
# Sirhan Sirhan: Robert Kennedy assassin stabbed in prison
#
# Cluster  998
# N.Korea says Pompeo remark would make talks with U.S. more difficult
# North Korea says Pompeo remark would make talks with U.S. more difficult
# North Korea says Pompeo's remarks make talks with U.S. more difficult
#
# Cluster  893
# This chant brought down the Berlin Wall. Now the far-right has stolen it
# This chant brought down the Berlin Wall. Now the far-right has stolen it
# This chant brought down the Berlin Wall. Now the far-right has stolen it
#
# Cluster  813
# Iran minister indicates satellite undamaged after failed launch
# UPDATE 1-Iran shows off undamaged satellite after failed launch
# Iran shows off undamaged satellite after failed launch
# Iran displays satellite after Trump tweet showing damaged launch site
#
# Cluster  1223
# Afghan government says Taliban attacking city of Kunduz
# Taliban attack northern Afghan city amid peace talks with U.S.
# Taliban launches 'massive' attack on Kunduz in northern Afghanistan
# Taliban launches large-scale attack on key Afghan city as talks with U.S. continue
# Taliban forces attack Afghan city amid peace talks with U.S.
# Taliban launch ‘massive attack’ on Afghan city of Kunduz
# Taliban, Afghan forces clash in northern Afghan city amid peace talks with U.S.
# Taliban launch 'massive attack' on northern Afghanistan city, government says
# Taliban suicide bomber hits Afghan police as Kunduz siege continues
# Scores killed as Taliban, Afghan forces clash in Kunduz despite peace talks
#
# Cluster  159
# Queensland extinguishes native title over Indigenous land to make way for Adani coalmine
# How the fight over brumbies is making the NSW Liberals and Nationals go feral
# ‘Nothing has changed’: why Queensland’s protest battle has raised Joh Bjelke-Petersen's ghost
#
# Cluster  345
# 'I was charged £20,000 for driving my car into the London emissions zone'
# Fraudsters target Chinese students in UK visa scam
#
# Cluster  1333
# Pensions: five reasons to think twice before putting it all in one pot
#
# Cluster  1394
# Climate Change Will Produce ‘Powerful Conflicts’
# North Carolina’s Climate Change Blind Spots Make Dorian More Dangerous
#
# Cluster  286
# Murat Cetinkaya, Oguzhan Ozbas appointed as Turkey central bank deputy governors
# New Austrian central bank head sets out hawkish line for ECB
#
# Cluster  23
# Valley Forge Park: A Visit Inspires Wonder
# He didn’t want to see anything “difficult.”
#
# Cluster  1374
# Review: ‘C.S. Lewis: A Very Short Introduction'
#
# Cluster  1274
# The Federalist Society Says It’s Not an Advocacy Organization. We Found Documents Showing Otherwise.
#
# Cluster  4
# Family of slain Honduran activist appeal to US court for help in her murder trial
# Ole Miss student's suspected killer indicted on capital murder charge
# Suit settled in teen suicide that led to Illinois law change
# Texas school district says a student was killed
#
# Cluster  1334
# UK finmin Javid says he has fantastic relationship with PM Johnson
# Britain's finance minister Javid says he has fantastic relationship with PM Johnson
# Britain's finance minister Javid says he has fantastic relationship with PM Johnson
#
# Cluster  926
# Iran official says U.S. showing 'some flexibility' on oil sales
# Iran official says U.S. showing 'some flexibility' on oil sales
#
# Cluster  130
# Black farmers say Warren’s farm plan wouldn’t solve their biggest problem
# South entrance for Potomac Yard Metro station still uncertain, even with extra money
#
# Cluster  838
# Couch potatoes have twice the risk of an early death, major study suggests
# Too old for president? Health and fitness a better question
#
# Cluster  537
# 12 dead, 50 injured in chemical factory blast in western India
# India chemical factory explosion kills 12 people
#
# Cluster  1257
# Sweden to introduce bank tax to fund greater defence spending - Fin Min
# Sweden to introduce bank tax to fund defense boost
#
# Cluster  959
# Hong Kong police use tear gas to try to disperse protests
# Hong Kong police use tear gas and water cannon to try to drive back protesters outside government headquarters
# Hong Kong police fire tear gas, water cannon in latest clashes
# Hong Kong police fire tear gas, water cannon as latest protests turn violent
# Hong Kong police fire tear gas as protesters hurl petrol bombs
# Hong Kong police fire tear gas as protesters hurl petrol bombs
# Tear Gas and Petrol Bombs as Hong Kongers Defy Regime Protest Ban
# Hong Kong protests turn to chaos amid tear gas and petrol bombs
# Hong Kong protesters set fires, police shoot tear gas in 13th consecutive weekend of anti-government demonstrations
# Hong Kong police fire tear gas as march turns into violent chaos
# Hong Kong commercial centers paralyzed as protesters, police exchange petrol bombs and tear gas
#
# Cluster  693
# Sudan's ex-president Bashir charged with corruption, holding illicit foreign currency
# Sudan court will resume al-Bashir trial next week
# Sudan's ex-president Bashir charged with corruption, holding illicit foreign currency
#
# Cluster  902
# Trump stresses legal actions over confidentiality in wake of Westerhout firing
# I Am 'Suing Various People' for Breaching Confidentiality
# Trump Claims There Could Be Legal Consequences For Former Staffers
#
# Cluster  1368
# Denmark honors savior of Chinese during Nanjing Massacre
#
# Cluster  1155
# Asylum-seeker arrested in France knife attack that left 1 dead, 9 wounded
# France: Manhunt after 1 killed, 6 injured in knife attack
# Knife attack kills 1, injures 9 in France; suspect detained
# One dead, nine wounded in France after suspected knife attack
#
# Cluster  928
# From a picnic to the Berlin Wall: my 1989 summer of revolution
# One Holocaust descendant's fight for justice: 'They stole not just our land, but my family's history'
#
# Cluster  1072
# Merkel hints at return to academia after politics
# 'Earthquake' elections in east Germany could jolt Merkel's coalition
#
# Cluster  971
# U.S. likely to toughen sanctions on Russia: secretary Perry
# U.S. to help Poland, Ukraine disconnect from Russian gas
# U.S. to help Poland, Ukraine disconnect from Russian gas
#
# Cluster  1087
# Turkey to launch own Syria plan unless it secures control of 'safe zone': Erdogan
# Erdogan vows Syria operation in weeks if US delays safe zone
# Turkey to launch own Syria plan in weeks unless has 'safe zone' control: Erdogan
#
# Cluster  497
# Earthquake fault long thought dormant could devastate L.A.
# DeSantis--and Florida--in the storm spotlight
#
# Cluster  718
# Trump at golf club after going to Camp David to track storm
# Trump meets with FEMA officials at Camp David to prepare for Hurricane Dorian
# Trump golfs as East Coast braces for catastrophic hurricane
# Trump Golfs and Tweets After Canceling Poland Trip to Keep Track of Hurricane Dorian
#
# Cluster  1083
# Brazil's Bolsonaro Vows To Stop Using Bic Pens Amid Spat With France's Macron
# Brazil's Bolsonaro Vows To Stop Using Bic Pens Amid Spat With France's Macron
# Brazil’s Bolsonaro stops using France’s Bic pens amid clash
#
# Cluster  1175
# Maryland man sentenced to 30 months in prison for role in $20M Ponzi scheme
# Man gets 30 months in prison for role in Ponzi scheme
# Man gets 30 months in prison for role in $20M Ponzi scheme
#
# Cluster  711
# 4th Democratic debate for the 2020 presidential primary race will be in Ohio on Oct. 15
# Democratic debate 2019: DNC announces rules for October primary debates
# Ohio to host October presidential primary debate
#
# Cluster  1244
# Ruptured pipeline in Nigeria's Delta state spilled oil: NNPC chief
#
# Cluster  868
# From Bodmin to Berlin, crowds vent their fury at Boris Johnson’s ‘coup’
# PM ‘must launch urgent inquiry into Dominic Cummings’s reign of terror’
# Newspaper headlines: 'Brexit endgame' and Johnson warning for rebels
#
# Cluster  1404
# Three Large Migrant Groups Apprehended Crossing Arizona Border
#
# Cluster  1392
# O'Rourke, Castro condemn fatal Texas mass shooting
# Beto Pushes Gun Control Rhetoric Before Midland, Odessa Facts Known
#
# Cluster  1199
# 818 Hotdogs Eaten Every Second from Memorial to Labor Day
#
# Cluster  1060
# Group protests development at historic McMillan Reservoir site
# Park Ridge surveys residents on support, opposition to marijuana businesses
#
# Cluster  53
# 'America is sick of this': Democrats renew call for tighter gun laws after West Texas shootings
# Shooter targets people at shopping centers in West Texas
# Shooter targets people at shopping centers in West Texas
# Gunmen in West Texas leave multiple gunshot victims.
# Gunmen in West Texas leave multiple gunshot victims.
#
# Cluster  1332
# Philip Green prepares to break up his Arcadia Group: Sunday Times
#
# Cluster  362
# Allan Fels: Australia’s consumer crusader on going public about his private life
# Fears Australia being turned ‘into a prison’ after surge in electronic monitoring of offenders
#
# Cluster  1400
# Leslie H. Gelb, journalist, think-tank leader and foreign policy expert, dies at 82

# %%
df_polusa["cluster"] = clustering_model.labels_

# %%
df_cluster = df_polusa.loc[df_polusa["cluster"]==125]
df_cluster["headline"].values
# Out:
# array(['Water Scarcity Is A Growing Problem. We Can Use Satellites To Better Measure It.',
#        'Are water shortages driving migration? Researchers dispel myths',
#        "Water costs are rising across the U.S. - here's why",
#        'More people, less water? Scientists see risks on upper Nile',
#        'More people, less water? Scientists see risks on upper Nile'],
#       dtype=object)

# %% [markdown]
# ## c-TF-IDF

# %%
# docs_df = pd.DataFrame(data, columns=["Doc"])
# docs_df['Topic'] = cluster.labels_
df_polusa['doc_id'] = range(len(df_polusa))
docs_per_topic = df_polusa.groupby(['cluster'], as_index = False).agg({'head_lead': ' '.join})

# %%
docs_per_topic.head()
# Out:
#    cluster                                          head_lead
# 0        0  An Interview with former U.S. Ambassador to Ru...
# 1        1  Former Google engineer charged with trade secr...
# 2        2  Pew: Twitter Dominated by Young Affluent Democ...
# 3        3  How has Brexit vote affected the UK economy? A...
# 4        4  Family of slain Honduran activist appeal to US...

# %%
def c_tf_idf(documents, m, ngram_range=(1, 1)):
    count = CountVectorizer(ngram_range=ngram_range, stop_words="english").fit(documents)
    t = count.transform(documents).toarray()
    w = t.sum(axis=1)
    tf = np.divide(t.T, w)
    sum_t = t.sum(axis=0)
    idf = np.log(np.divide(m, sum_t)).reshape(-1, 1)
    tf_idf = np.multiply(tf, idf)

    return tf_idf, count

# %%
tf_idf, count = c_tf_idf(docs_per_topic["head_lead"].values, m=len(data))

# %%
def extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20):
    words = count.get_feature_names()
    labels = list(docs_per_topic["cluster"])
    tf_idf_transposed = tf_idf.T
    indices = tf_idf_transposed.argsort()[:, -n:]
    top_n_words = {label: [(words[j], tf_idf_transposed[i][j]) for j in indices[i]][::-1] for i, label in enumerate(labels)}
    return top_n_words

def extract_topic_sizes(df):
    topic_sizes = (df.groupby(['cluster'])
                     .head_lead
                     .count()
                     .reset_index()
                     .rename({"cluster": "cluster", "head_lead": "Size"}, axis='columns')
                     .sort_values("Size", ascending=False))
    return topic_sizes

# %%
top_n_words = extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20)
topic_sizes = extract_topic_sizes(df_polusa); topic_sizes.head(10)
# Out:
#      cluster  Size
# 261      261    22
# 61        61    20
# 141      141    19
# 927      927    19
# 203      203    18
# 610      610    17
# 119      119    17
# 500      500    17
# 200      200    16
# 195      195    16

# %% [markdown]
# ## Filter out articles with not enough top words

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/matthewlucich/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
ps = PorterStemmer()

def clean_headline_lead(text):
    art_words = re.sub(r'[^\w\s]', '', text)
    art_words = word_tokenize(art_words)
    art_words_lower = [x.lower() for x in art_words]
    art_words_no_stop = [word for word in art_words_lower if not word in stopwords.words()]
    art_words_lower_stem = [ps.stem(word) for word in art_words_no_stop]
    return art_words_lower_stem

# %%
df_cluster["top_words_article"] = df_cluster["head_lead"].apply(clean_headline_lead)

# %%
df_cluster.iloc[0, 13]
# Out:
# ['water',
#  'scarciti',
#  'grow',
#  'problem',
#  'use',
#  'satellit',
#  'better',
#  'measur',
#  'itth',
#  'problem',
#  'could',
#  'affect',
#  'much',
#  '80',
#  'peopl',
#  'africa',
#  '2050']

# %%
df_cluster["num_top_words"] = df_cluster["head_lead"].apply(clean_headline_lead)

# %%
len(set(df_polusa["cluster"]))
# Out:
# 1420

# %%
df_polusa.columns
# Out:
# Index(['id', 'date_publish', 'outlet', 'headline', 'lead', 'body', 'authors',
#        'domain', 'url', 'political_leaning', 'head_lead', 'cluster', 'doc_id'],
#       dtype='object')

# %%
df_labeled = pd.DataFrame(columns = ['id', 'date_publish', 'outlet', 'headline', 'lead', 'body', 'authors',
       'domain', 'url', 'political_leaning', 'head_lead', 'cluster', 'doc_id', 'cluster_terms', 'match_terms', 'num_match'])

for cluster in set(df_polusa["cluster"]):
    word_list_cluster = [word[0] for word in top_n_words[cluster][:15]]
    word_list_cluster_lower = [x.lower() for x in word_list_cluster]
    word_list_cluster_no_stop = [word for word in word_list_cluster_lower if not word in stopwords.words()]
    word_list_cluster_stem = [ps.stem(word) for word in word_list_cluster_no_stop]
    word_list_cluster_stem = word_list_cluster_stem[:10]
    df_clus = df_polusa.loc[df_polusa["cluster"]==cluster]
    df_clus["top_words_article"] = df_clus["head_lead"].apply(clean_headline_lead)
    #print("CLUSTER TOP WORDS:", str(cluster))
    #print(word_list_cluster_stem)
    for index, row in df_clus.iterrows():
        df_labeled = df_labeled.append({'id': row["id"], 'date_publish': row["date_publish"], 
                                      'outlet':row["outlet"], 'headline': row["headline"], 
                                      'lead': row["lead"], 'body': row["body"], 'authors': row["authors"],
                                      'domain': row["domain"], 'url': row["url"], 
                                      'political_leaning': row["political_leaning"], 
                                      'head_lead': row["head_lead"], 'cluster': row["cluster"], 
                                      'doc_id': row["doc_id"], 'cluster_terms': word_list_cluster_stem,
                                      'article_terms': row["top_words_article"],
                                      'match_terms': list(set(word_list_cluster_stem) & set(row["top_words_article"])),
                                      'num_match': len(list(set(word_list_cluster_stem) & set(row["top_words_article"])))},
                                       ignore_index = True)

# %%
# Create new dataframe
# Append row if cluster is good

# %%
df_labeled.tail()
# Out:
#             id         date_publish               outlet  \
# 4995  38996999  2019-08-31 15:56:17         The Guardian
# 4996  45658582  2019-08-30 08:35:11  The Washington Post
# 4997   2824670  2019-08-30 09:21:48              Reuters
# 4998   4352555  2019-08-30 16:16:19            Breitbart
# 4999   1156862  2019-08-30 16:40:55              Reuters
#
#                                                headline  \
# 4995  Javid defends settled status scheme in respons...
# 4996  About 100 migrants jump fences into Spanish Af...
# 4997  Over 150 migrants storm through Spain's enclav...
# 4998  150+ African Migrants Storm Border Fence, Ente...
# 4999  Over 150 migrants break into Spanish North Afr...
#
#                                                    lead  \
# 4995  Campaigners point to rise in grants for pre-se...
# 4996  Authorities in Ceuta say that around 100 migra...
# 4997  More than 150 migrants crossed the border fenc...
# 4998  At least 155 migrants from Sub-Saharan Africa ...
# 4999  More than 150 migrants crossed the border fenc...
#
#                                                    body  \
# 4995  Campaigners point to rise in grants for pre-se...
# 4996  MADRID — Authorities in Ceuta say that around ...
# 4997  A migrant leaves the Spanish military ship 'Au...
# 4998  MADRID (AP) – At least 155 migrants from Sub-S...
# 4999  SAN ROQUE, Spain (Reuters) - More than 150 mig...
#
#                                           authors                  domain  \
# 4995  Nadeem Badshah;Marley Morris;Marie Le Conte     www.theguardian.com
# 4996                Associated Press;August At Am  www.washingtonpost.com
# 4997                   Reuters Editorial;Min Read         www.reuters.com
# 4998                             Breitbart London       www.breitbart.com
# 4999                           Jon Nazca;Min Read         www.reuters.com
#
#                                                     url political_leaning  \
# 4995  https://www.theguardian.com/politics/2019/aug/...              LEFT
# 4996  https://www.washingtonpost.com/world/europe/ab...         UNDEFINED
# 4997  https://www.reuters.com/article/us-europe-migr...            CENTER
# 4998  https://www.breitbart.com/europe/2019/08/30/15...             RIGHT
# 4999  https://www.reuters.com/article/us-europe-migr...            CENTER
#
#                                               head_lead cluster doc_id  \
# 4995  Javid defends settled status scheme in respons...    1418   4853
# 4996  About 100 migrants jump fences into Spanish Af...    1419   3663
# 4997  Over 150 migrants storm through Spain's enclav...    1419   3696
# 4998  150+ African Migrants Storm Border Fence, Ente...    1419   4147
# 4999  Over 150 migrants break into Spanish North Afr...    1419   4173
#
#                                           cluster_terms  \
# 4995  [javid, fiscal, settl, statu, break, review, s...
# 4996  [enclav, migrant, spanish, 150, ceuta, fenc, a...
# 4997  [enclav, migrant, spanish, 150, ceuta, fenc, a...
# 4998  [enclav, migrant, spanish, 150, ceuta, fenc, a...
# 4999  [enclav, migrant, spanish, 150, ceuta, fenc, a...
#
#                                             match_terms num_match  \
# 4995                       [javid, statu, settl, grant]         4
# 4996  [spanish, african, cross, ceuta, enclav, fenc,...         7
# 4997  [spanish, spain, 150, african, ceuta, cross, e...         9
# 4998  [spanish, 150, african, ceuta, enclav, fenc, m...         7
# 4999  [spanish, spain, 150, african, ceuta, cross, e...         9
#
#                                           article_terms
# 4995  [javid, defend, settl, statu, scheme, respons,...
# 4996  [100, migrant, jump, fenc, spanish, african, e...
# 4997  [150, migrant, storm, spain, enclav, fencemor,...
# 4998  [150, african, migrant, storm, border, fenc, e...
# 4999  [150, migrant, break, spanish, north, african,...

# %%
df_labeled.shape
# Out:
# (5000, 17)

# %%
df_labeled = df_labeled.loc[df_labeled["num_match"]>=4]

# %% [markdown]
# ## Filter out low quality clusters (e.g. less than 3 articles, one source)

# %%
low_quality_clusters = []
for cluster in set(df_labeled["cluster"]):
    df_clust = df_labeled.loc[df_labeled["cluster"]==cluster]
    if df_clust.shape[0] < 3:
        low_quality_clusters.append(cluster)
    elif len(set(df_clust["outlet"])) < 2:
        low_quality_clusters.append(cluster)

# %%
len(low_quality_clusters)
# Out:
# 968

# %%
df_good = df_labeled.loc[~df_labeled["cluster"].isin(low_quality_clusters)]

# %%
set(df_good["cluster"])
# Out:
# {1,
#  3,
#  5,
#  12,
#  13,
#  17,
#  18,
#  22,
#  26,
#  28,
#  30,
#  33,
#  34,
#  35,
#  36,
#  40,
#  42,
#  47,
#  49,
#  50,
#  53,
#  56,
#  57,
#  59,
#  61,
#  66,
#  68,
#  69,
#  70,
#  75,
#  77,
#  78,
#  84,
#  86,
#  90,
#  92,
#  97,
#  101,
#  102,
#  104,
#  113,
#  114,
#  117,
#  119,
#  124,
#  125,
#  135,
#  136,
#  139,
#  141,
#  142,
#  143,
#  150,
#  151,
#  157,
#  161,
#  165,
#  168,
#  170,
#  183,
#  186,
#  188,
#  193,
#  194,
#  195,
#  199,
#  203,
#  204,
#  215,
#  216,
#  218,
#  230,
#  235,
#  239,
#  244,
#  246,
#  252,
#  256,
#  257,
#  260,
#  261,
#  266,
#  267,
#  268,
#  270,
#  277,
#  278,
#  279,
#  283,
#  284,
#  285,
#  291,
#  292,
#  293,
#  295,
#  305,
#  306,
#  307,
#  309,
#  313,
#  314,
#  320,
#  324,
#  329,
#  331,
#  333,
#  341,
#  347,
#  349,
#  350,
#  352,
#  355,
#  356,
#  358,
#  359,
#  361,
#  367,
#  368,
#  369,
#  377,
#  379,
#  387,
#  388,
#  390,
#  391,
#  392,
#  393,
#  394,
#  395,
#  396,
#  402,
#  404,
#  407,
#  410,
#  411,
#  413,
#  417,
#  418,
#  420,
#  422,
#  423,
#  425,
#  427,
#  431,
#  437,
#  440,
#  441,
#  449,
#  456,
#  457,
#  458,
#  459,
#  465,
#  468,
#  470,
#  471,
#  473,
#  474,
#  475,
#  476,
#  482,
#  485,
#  489,
#  500,
#  501,
#  504,
#  507,
#  510,
#  512,
#  514,
#  515,
#  522,
#  525,
#  542,
#  543,
#  547,
#  552,
#  555,
#  558,
#  559,
#  560,
#  561,
#  573,
#  576,
#  577,
#  581,
#  584,
#  587,
#  589,
#  591,
#  594,
#  595,
#  599,
#  602,
#  609,
#  610,
#  613,
#  622,
#  623,
#  624,
#  625,
#  630,
#  635,
#  643,
#  645,
#  647,
#  649,
#  650,
#  652,
#  655,
#  656,
#  657,
#  658,
#  665,
#  670,
#  671,
#  673,
#  674,
#  675,
#  677,
#  679,
#  680,
#  693,
#  696,
#  701,
#  703,
#  704,
#  709,
#  711,
#  712,
#  713,
#  715,
#  716,
#  718,
#  719,
#  720,
#  721,
#  727,
#  730,
#  731,
#  734,
#  738,
#  743,
#  745,
#  750,
#  754,
#  755,
#  756,
#  757,
#  760,
#  763,
#  768,
#  776,
#  779,
#  780,
#  782,
#  785,
#  787,
#  789,
#  790,
#  791,
#  802,
#  813,
#  814,
#  816,
#  818,
#  819,
#  820,
#  827,
#  828,
#  831,
#  832,
#  836,
#  837,
#  840,
#  843,
#  847,
#  848,
#  849,
#  856,
#  861,
#  862,
#  870,
#  872,
#  873,
#  877,
#  884,
#  885,
#  886,
#  889,
#  892,
#  899,
#  904,
#  907,
#  908,
#  909,
#  912,
#  914,
#  920,
#  924,
#  927,
#  936,
#  940,
#  942,
#  948,
#  950,
#  951,
#  959,
#  963,
#  969,
#  976,
#  977,
#  981,
#  982,
#  983,
#  985,
#  986,
#  988,
#  989,
#  990,
#  991,
#  993,
#  997,
#  1000,
#  1007,
#  1011,
#  1015,
#  1016,
#  1018,
#  1020,
#  1021,
#  1023,
#  1029,
#  1031,
#  1033,
#  1034,
#  1037,
#  1041,
#  1042,
#  1043,
#  1045,
#  1046,
#  1047,
#  1050,
#  1053,
#  1054,
#  1055,
#  1058,
#  1061,
#  1071,
#  1073,
#  1079,
#  1080,
#  1082,
#  1083,
#  1084,
#  1087,
#  1089,
#  1095,
#  1097,
#  1100,
#  1103,
#  1106,
#  1108,
#  1124,
#  1125,
#  1126,
#  1129,
#  1130,
#  1137,
#  1139,
#  1141,
#  1143,
#  1144,
#  1146,
#  1147,
#  1151,
#  1155,
#  1157,
#  1159,
#  1162,
#  1169,
#  1175,
#  1176,
#  1178,
#  1180,
#  1181,
#  1183,
#  1190,
#  1192,
#  1195,
#  1202,
#  1203,
#  1207,
#  1209,
#  1211,
#  1216,
#  1222,
#  1223,
#  1227,
#  1229,
#  1231,
#  1236,
#  1240,
#  1247,
#  1249,
#  1250,
#  1254,
#  1258,
#  1263,
#  1265,
#  1268,
#  1277,
#  1293,
#  1294,
#  1295,
#  1298,
#  1304,
#  1308,
#  1311,
#  1313,
#  1319,
#  1320,
#  1322,
#  1323,
#  1326,
#  1328,
#  1330,
#  1331,
#  1335,
#  1340,
#  1344,
#  1356,
#  1359,
#  1361,
#  1364,
#  1367,
#  1376,
#  1377,
#  1378,
#  1386,
#  1389,
#  1391,
#  1402,
#  1419}

# %%
num_clust = 18
df_qa = df_good.loc[df_good["cluster"]==num_clust]
df_qa["headline"].values
# Out:
# array(["Violence Follows Pro-Independence Protests In Indonesia's Papua Region",
#        "Explainer: Deepening unrest in Indonesia's Papua",
#        'Protesters burn local assembly building in Papua protest',
#        "Violent protest erupts in capital of Indonesia's Papua",
#        "Violent protest erupts in capital of Indonesia's Papua",
#        'Indonesia urges calm in Papua after two weeks of protests'],
#       dtype=object)

# %%
df_good.loc[df_good["cluster"]==num_clust]
# Out:
#            id         date_publish               outlet  \
# 99   52874105  2019-08-28 00:00:00                  NPR
# 100   3407626  2019-08-29 05:39:28              Reuters
# 101  45838358  2019-08-29 09:53:32  The Washington Post
# 102   2598373  2019-08-29 11:36:46              Reuters
# 103   1191947  2019-08-29 12:41:22              Reuters
# 104   3313117  2019-08-30 11:23:59              Reuters
#
#                                               headline  \
# 99   Violence Follows Pro-Independence Protests In ...
# 100   Explainer: Deepening unrest in Indonesia's Papua
# 101  Protesters burn local assembly building in Pap...
# 102  Violent protest erupts in capital of Indonesia...
# 103  Violent protest erupts in capital of Indonesia...
# 104  Indonesia urges calm in Papua after two weeks ...
#
#                                                   lead  \
# 99   Tensions between pro-independence supporters a...
# 100  Indonesia's easternmost provinces of Papua and...
# 101  Police say protesters in Indonesia’s restive P...
# 102  Protesters in Indonesia's easternmost region o...
# 103  Protesters in Indonesia's easternmost region o...
# 104  Indonesia's chief security minister on Friday ...
#
#                                                   body  \
# 99   Violence Follows Pro-Independence Protests In ...
# 100  (Reuters) - Indonesia’s easternmost provinces ...
# 101  A Papuan student with her face painted with th...
# 102  JAKARTA (Reuters) - Protesters in Indonesia’s ...
# 103  JAKARTA (Reuters) - Protesters in Indonesia’s ...
# 104  JAKARTA (Reuters) - Indonesia’s chief security...
#
#                            authors                  domain  \
# 99                Ashley Westerman             www.npr.org
# 100            Tom Allard;Min Read         www.reuters.com
# 101  Associated Press;August At Am  www.washingtonpost.com
# 102     Reuters Editorial;Min Read         www.reuters.com
# 103     Reuters Editorial;Min Read         www.reuters.com
# 104     Reuters Editorial;Min Read         www.reuters.com
#
#                                                    url political_leaning  \
# 99   https://www.npr.org/2019/08/28/754276641/viole...              LEFT
# 100  https://www.reuters.com/article/us-indonesia-p...            CENTER
# 101  https://www.washingtonpost.com/world/asia_paci...         UNDEFINED
# 102  https://www.reuters.com/article/us-indonesia-p...            CENTER
# 103  https://www.reuters.com/article/us-indonesia-p...            CENTER
# 104  https://www.reuters.com/article/us-indonesia-p...            CENTER
#
#                                              head_lead cluster doc_id  \
# 99   Violence Follows Pro-Independence Protests In ...      18    503
# 100  Explainer: Deepening unrest in Indonesia's Pap...      18   2120
# 101  Protesters burn local assembly building in Pap...      18   2305
# 102  Violent protest erupts in capital of Indonesia...      18   2418
# 103  Violent protest erupts in capital of Indonesia...      18   2503
# 104  Indonesia urges calm in Papua after two weeks ...      18   3830
#
#                                          cluster_terms  \
# 99   [papua, indonesia, easternmost, region, capit,...
# 100  [papua, indonesia, easternmost, region, capit,...
# 101  [papua, indonesia, easternmost, region, capit,...
# 102  [papua, indonesia, easternmost, region, capit,...
# 103  [papua, indonesia, easternmost, region, capit,...
# 104  [papua, indonesia, easternmost, region, capit,...
#
#                                            match_terms num_match  \
# 99                [papua, provinc, indonesia, protest]         4
# 100           [easternmost, papua, provinc, indonesia]         4
# 101               [papua, provinc, indonesia, protest]         4
# 102  [indonesia, region, protest, easternmost, viol...         9
# 103  [indonesia, region, protest, easternmost, viol...         9
# 104  [indonesia, region, protest, easternmost, viol...         6
#
#                                          article_terms
# 99   [violenc, follow, proindepend, protest, indone...
# 100  [explain, deepen, unrest, indonesia, papuaindo...
# 101  [protest, burn, local, assembl, build, papua, ...
# 102  [violent, protest, erupt, capit, indonesia, pa...
# 103  [violent, protest, erupt, capit, indonesia, pa...
# 104  [indonesia, urg, calm, papua, two, week, prote...

# %% [markdown]
# ## Highlight Event Selection

# %%
import statistics

# %%
df_event_selection = pd.DataFrame(columns = ["cluster", "median_date", "covered", "not_covered", "cluster_terms"])
all_outlets = set(df_polusa["outlet"])
for cluster in set(df_good["cluster"]):
    df_clust = df_good.loc[df_good["cluster"]==cluster]
    clust_outlets = set(df_clust["outlet"])
    did_not_cover = all_outlets - clust_outlets
    date_list = pd.to_datetime(df_clust["date_publish"], infer_datetime_format=True)
    median_date = pd.Timestamp.fromordinal(int(date_list.apply(lambda x: x.toordinal()).median()))
    df_event_selection = df_event_selection.append({'cluster': cluster, 'median_date': median_date, 
                                       'covered': clust_outlets, 'not_covered': did_not_cover, 
                                        'cluster_terms': df_clust["cluster_terms"].iloc[0]},
                                       ignore_index = True)

# %%
df_event_selection.tail(10)
# Out:
#     cluster median_date                                            covered  \
# 435    1364  2019-08-28       {The Guardian, Reuters, The Washington Post}
# 436    1367  2019-08-31  {Reuters, NBC News, Yahoo! News, The Washingto...
# 437    1376  2019-08-27  {Chicago Tribune, Reuters, NBC News, Yahoo! Ne...
# 438    1377  2019-08-29                               {CBS News, NBC News}
# 439    1378  2019-08-29      {USA Today, Yahoo! News, The Washington Post}
# 440    1386  2019-08-27  {CNN, Yahoo! News, The Guardian, Fox News, The...
# 441    1389  2019-08-30                                    {CNN, NBC News}
# 442    1391  2019-08-28                  {Breitbart, Yahoo! News, Reuters}
# 443    1402  2019-08-30                     {Reuters, The Washington Post}
# 444    1419  2019-08-30          {Breitbart, Reuters, The Washington Post}
#
#                                            not_covered  \
# 435  {PBS, The Daily Caller, NBC News, Politico, AB...
# 436  {PBS, The Daily Caller, Politico, ABC News, BB...
# 437  {CNN, PBS, The Daily Caller, Politico, Nationa...
# 438  {PBS, The Daily Caller, Politico, ABC News, BB...
# 439  {PBS, The Daily Caller, NBC News, Politico, AB...
# 440  {PBS, Chicago Tribune, Reuters, The Daily Call...
# 441  {PBS, The Daily Caller, Politico, ABC News, BB...
# 442  {PBS, The Daily Caller, NBC News, Politico, AB...
# 443  {PBS, The Daily Caller, NBC News, Politico, AB...
# 444  {PBS, The Daily Caller, NBC News, Politico, AB...
#
#                                          cluster_terms
# 435  [davidson, leader, conserv, quit, ruth, scotla...
# 436  [sirhan, prison, robert, stab, kennedi, assass...
# 437  [missouri, judg, abort, law, feder, ban, block...
# 438  [children, polici, ill, die, deport, sick, tru...
# 439  [minnesota, omar, threat, fair, hate, democrat...
# 440  [harvard, friend, freshman, entri, palestinian...
# 441  [suicid, philadelphia, weapon, home, arsen, gr...
# 442  [facebook, quit, research, democraci, impact, ...
# 443  [swap, prison, ukrain, russia, ukrainian, film...
# 444  [enclav, migrant, spanish, 150, ceuta, fenc, a...

# %%
regex_str = "Ukraine|prison|swap"
outlet = 'Reuters'
df_polusa.loc[(df_polusa["outlet"]==outlet)
             & (df_polusa["head_lead"].str.contains(regex_str))]["headline"].values
# Out:
# array(["Deputy head of presidential office may serve as Ukraine's next premier",
#        'At least one killed in gas explosion in Ukraine',
#        'Ukraine frees jailed Russian journalist Vyshinsky on bail: TASS',
#        'Ukraine frees jailed Russian journalist amid prisoner swap talks',
#        'Trump adviser Bolton, in Ukraine, warns of Chinese influence',
#        'Trump adviser Bolton, in Ukraine, warns of Chinese influence',
#        'Trump adviser Bolton tells Ukraine: Beware Chinese influence',
#        "China's yuan struggles to find floor as tariffs loom",
#        "South Korea's top court orders review of ex-president Park's graft case",
#        'Myanmar jails filmmaker for Facebook posts critical of military',
#        'Jailed Ukrainian filmmaker brought to Moscow amid prisoner swap talks: Russian media',
#        'Ukraine President nominates new foreign, defense ministers',
#        'Ukraine president proposes to appoint Honcharuk as prime minister',
#        'Ukraine president proposes political novice Honcharuk as prime minister',
#        'Trump considering blocking military aid to Ukraine: CNN',
#        'Ukraine PM nominee says government to talk with IMF over new program',
#        "Wakeboarder, wrestler, dentist: novices of Ukraine's new ruling party take over parliament",
#        'Ukrainian parliament appoints Honcharuk as new prime minister',
#        "Wakeboarder, wrestler, dentist: novices of Ukraine's new ruling party take over parliament",
#        'Ukraine parliament appoints new defense minister',
#        'Ukrainian parliament appoints Honcharuk as new prime minister',
#        'Political novice Honcharuk appointed Ukraine PM, to focus on economy',
#        'Trump may block $250 million in aid to Ukraine: officials',
#        'Singapore moves to switch bank lending rate benchmarks',
#        'Ukraine official says Ukraine, Russia swapped prisoners, including sailors',
#        "Ukraine president's office says no prisoner swap with Russia yet",
#        "Ukraine president's office says no prisoner swap with Russia yet",
#        'UPDATE 1-Ferrexpo says review finds some funds to Ukraine charity could have been "misappropriated"',
#        'China to help rate risk-hedging by improving liquidity of derivatives',
#        'CANADA FX DEBT-C$ strengthens as economy expands faster than expected',
#        "Chinese envoy tells U.S. not to meddle in Ukraine's affairs",
#        'Ukraine looks at U.S. LNG as part of diversification plan',
#        'Convicted RFK assassin Sirhan Sirhan stabbed in California prison: reports',
#        'U.S. likely to toughen sanctions on Russia: secretary Perry',
#        'U.S. to help Poland, Ukraine disconnect from Russian gas',
#        'U.S. to help Poland, Ukraine disconnect from Russian gas'],
#       dtype=object)

# %%
df_polusa_raw.loc[(df_polusa_raw["outlet"]==outlet)
             & (df_polusa_raw["headline"].str.contains(regex_str))]["headline"].values
# Out:
# array(['Judge in census case denies DOJ motion to swap out lawyers',
#        'Patronis v. Rubin heats up — Florida Democrats remain cautious on impeachment talk — Bad ballot design cost Nelson — Are prisons ready for hurricane season?',
#        'Prosecutors back Pell Grants for prisoners',
#        'A gun control swap for immigration reform?',
#        'U.S. prisons chief removed after Epstein’s death',
#        'Trump fuels outsize expectations that Russia investigators will face prison time',
#        'Rick Gates says he told Vin Weber and Tony Podesta that Ukraine controlled think tank',
#        'Pentagon wants Ukraine military aid to continue',
#        'Vin Weber resigns from lobbying firm after scrutiny over Ukraine work with Manafort'],
#       dtype=object)

# %%
#df_polusa_raw.loc[df_polusa_raw["id"]==131771587]

# %%
df_good.loc[df_good["cluster"]==1402]["headline"].values
# Out:
# array(['Jailed Ukrainian filmmaker brought to Moscow amid prisoner swap talks: Russian media',
#        'Ukraine official says Ukraine, Russia swapped prisoners, including sailors',
#        "Ukraine president's office says no prisoner swap with Russia yet",
#        'Ukraine says major prisoner exchange with Russia underway',
#        "Ukraine president's office says no prisoner swap with Russia yet",
#        'Ukraine denies reports of prisoner swap with Russia'],
#       dtype=object)

# %%
#set(df_polusa["outlet"])

# %%
#set(df_qa["outlet"])

# %%
#set(df_polusa["outlet"]) - set(df_qa["outlet"])

# %%
# df_polusa.loc[(df_polusa["outlet"]=='The New York Times')
#              & (df_polusa["head_lead"].str.contains("Citizenship"))]["headline"].values

# %%
# df_polusa_raw.loc[(df_polusa_raw["outlet"]=='The New York Times')
#              & (df_polusa_raw["headline"].str.contains("Uber"))]["headline"].values

# %%
# df_polusa.loc[(df_polusa["outlet"]=='The New York Times') & 
#               (df_polusa["date_publish"] > min(df_polusa["date_publish"])) & (df_polusa["date_publish"] < max(df_polusa["date_publish"]))
#              ]["headline"].values

# %%
#df_event_selection.to_csv("event_selection_1.csv")

# %%
#df_good.to_csv("good_clusters_1.csv")
